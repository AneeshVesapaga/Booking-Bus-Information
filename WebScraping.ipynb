# %%
from selenium.webdriver.common.by import By
from selenium import webdriver
import requests
from bs4 import BeautifulSoup
import re
import time
import pandas as pd

# %%
url = "https://www.redbus.in/online-booking/tsrtc/?utm_source=rtchometile"

# %%
page = requests.get(url)

# %%
page.text
# Out:
# '<!DOCTYPE html>\n        <html lang="en">\n        <head>\n               <title>TSRTC Online  Bus Ticket Booking, Bus Reservation, Time Table, Fares - redBus.in</title>\n               <link rel="canonical" href="https://www.redbus.in/online-booking/tsrtc">\n               <meta http-equiv="content-type" content="text/html; charset=UTF-8">\n               <meta name="viewport" content="initial-scale=1.0">\n               <meta name="description" content="Book TSRTC bus tickets online at redBus. Check TSRTC online bus fares, find time table and online bus ticket reservations with ZERO Booking Fees.">\n               <meta name="classification" content="Travel">\n               \n               \n                \n                \n                <meta name="robots" content="index, follow">\n                \n                <link rel="shortcut icon" type="image/ico" href="/seoassets/favicon.ico">\n                <link rel="preload" href="/seoassets/fonts/Montserrat-Regular.woff2" 
# ...

# %%
soup = BeautifulSoup(page.text)

# %%
a = soup.find_all("a",class_="route")

# %%
From_To = []
for i in a:
    From_To.append(i.text)

# %%
From_To
# Out:
# ['hyderabad-to-nandyala',
#  'khammam-to-hyderabad',
#  'hyderabad-to-khammam',
#  'hyderabad-to-srisailam',
#  'karimnagar-to-hyderabad',
#  'hyderabad-to-mancherial',
#  'hyderabad-to-karimnagar',
#  'hyderabad-to-nirmal',
#  'hyderabad-to-adilabad',
#  'hyderabad-to-ongole',
#  'kothagudem-to-hyderabad',
#  'guntur-to-hyderabad',
#  'hyderabad-to-guntur',
#  'hyderabad-to-kothagudem',
#  'hyderabad-to-sathupalli',
#  'hyderabad-to-warangal',
#  'kodad-to-hyderabad',
#  'jagityal-to-hyderabad',
#  'hyderabad-to-bhadrachalam',
#  'hyderabad-to-tirupathi',
#  'hyderabad-to-godavarikhani',
#  'hyderabad-to-armoor',
#  'hyderabad-to-vijayawada',
#  'vijayawada-to-hyderabad',
#  'kakinada-to-visakhapatnam',
#  'bangalore-to-tirupathi',
#  'bangalore-to-kadapa',
#  'ongole-to-hyderabad',
#  'kadapa-to-bangalore',
#  'visakhapatnam-to-kakinada',
#  'chittoor-to-bangalore',
#  'bangalore-to-ananthapur',
#  'bangalore-to-chittoor',
#  'ananthapur-to-bangalore',
#  'hyderabad-to-kurnool',
# ...

# %%
From_To = ['hyderabad-to-nandyala', 'khammam-to-hyderabad',
       'hyderabad-to-khammam', 'hyderabad-to-srisailam',
       'karimnagar-to-hyderabad', 'hyderabad-to-mancherial',
       'hyderabad-to-karimnagar', 'hyderabad-to-nirmal',
       'hyderabad-to-adilabad', 'hyderabad-to-ongole',
       'kothagudem-to-hyderabad', 'guntur-to-hyderabad',
       'hyderabad-to-guntur', 'hyderabad-to-kothagudem',
       'hyderabad-to-sathupalli', 'hyderabad-to-warangal',
       'kodad-to-hyderabad', 'jagityal-to-hyderabad',
       'hyderabad-to-bhadrachalam', 'hyderabad-to-tirupathi',
       'hyderabad-to-godavarikhani', 'hyderabad-to-armoor',
       'hyderabad-to-vijayawada', 'vijayawada-to-hyderabad',
       'kakinada-to-visakhapatnam', 'bangalore-to-tirupathi',
       'bangalore-to-kadapa', 'ongole-to-hyderabad',
       'kadapa-to-bangalore', 'visakhapatnam-to-kakinada',
       'chittoor-to-bangalore', 'bangalore-to-ananthapur',
       'bangalore-to-chittoor', 'ananthapur-to-bangalore',
       'hyderabad-to-kurnool', 'tirupathi-to-bangalore',
       'narsaraopet-to-hyderabad', 'vinukonda-to-hyderabad',
       'hyderabad-to-vinukonda', 'visakhapatnam-to-vijayawada',
       'bangalore-to-rayachoti', 'hyderabad-to-eluru',
       'eluru-to-hyderabad', 'bangalore-to-kadiri',
       'bangalore-to-madanapalli', 'madanapalli-to-bangalore',
       'rajahmundry-to-visakhapatnam', 'nandyala-to-hyderabad',
       'rayachoti-to-bangalore', 'kurnool-to-hyderabad',
       'kadiri-to-bangalore', 'visakhapatnam-to-rajahmundry',
       'hyderabad-to-addanki', 'hyderabad-to-markapuram',
       'hyderabad-to-ananthapur', 'rajahmundry-to-vijayawada',
       'vijayawada-to-visakhapatnam', 'hyderabad-to-macherla',
       'hyderabad-to-rajahmundry', 'chilakaluripet-to-hyderabad',
       'rajahmundry-to-hyderabad', 'kurnool-to-bangalore', 'pune-to-goa',
       'goa-to-pune', 'mumbai-to-goa', 'bangalore-to-goa',
       'goa-to-bangalore', 'goa-to-mumbai', 'goa-to-kolhapur',
       'pandharpur-to-goa', 'solapur-to-goa', 'goa-to-solapur',
       'goa-to-sangli', 'goa-to-sangola', 'sangola-to-goa',
       'goa-to-miraj', 'goa-to-mopa-airport', 'panaji-to-goa-airport',
       'mopa-airport-to-goa', 'bangalore-to-kozhikode',
       'kozhikode-to-bangalore', 'kozhikode-to-ernakulam',
       'ernakulam-to-kozhikode', 'bangalore-to-kannur',
       'kozhikode-to-mysore', 'kannur-to-bangalore',
       'kozhikode-to-thiruvananthapuram', 'bangalore-to-kalpetta',
       'kalpetta-to-bangalore', 'thiruvananthapuram-to-kozhikode',
       'kozhikode-to-thrissur', 'kozhikode-to-kottayam',
       'kottayam-to-kozhikode', 'udaipur-to-jodhpur', 'jodhpur-to-ajmer',
       'beawer-to-jaipur', 'sikar-to-jaipur', 'jaipur-to-jodhpur',
       'aligarh-to-jaipur', 'jaipur-to-mathura', 'jaipur-to-aligarh',
       'pali-to-udaipur', 'udaipur-to-pali', 'kota-to-udaipur',
       'jaipur-to-bhilwara', 'sikar-to-bikaner', 'jaipur-to-bharatpur',
       'jaipur-to-kota', 'durgapur-to-kolkata', 'kolkata-to-burdwan',
       'haldia-to-kolkata', 'kolkata-to-haldia', 'kolkata-to-durgapur',
       'midnapore-to-kolkata', 'kolkata-to-digha', 'digha-to-kolkata',
       'kolkata-to-midnapore', 'kolkata-to-asansol',
       'kolkata-to-nimtouri', 'kolkata-to-contai-kanthi',
       'kolkata-to-mecheda', 'kolkata-to-panskura', 'kolkata-to-heria',
       'kolkata-to-suri', 'illambazar-to-kolkata', 'kolkata-to-ashari',
       'kolkata-to-futishanko', 'kolkata-to-ramnagar', 'digha-to-barasat',
       'barasat-to-digha', 'delhi-to-shimla', 'chandigarh-to-hamirpur',
       'hamirpur-to-chandigarh', 'shimla-to-delhi', 'delhi-to-chandigarh',
       'hamirpur-to-delhi', 'chamba-to-chandigarh', 'delhi-to-hamirpur',
       'chandigarh-to-dharamshala', 'delhi-to-chamba',
       'kangra-to-chandigarh', 'shimla-to-chandigarh', 'delhi-to-solan',
       'dharamshala-to-chandigarh', 'palampur-to-chandigarh',
       'ghumarwin-to-delhi', 'chandigarh-to-kangra', 'baddi-to-delhi',
       'manali-to-chandigarh', 'solan-to-delhi', 'chandigarh-to-manali',
       'delhi-to-sarkaghat', 'ghumarwin-to-chandigarh',
       'chandigarh-to-kullu', 'delhi-to-palampur', 'bilaspur-to-delhi',
       'manali-to-delhi', 'delhi-to-bareilly', 'bareilly-to-delhi',
       'aligarh-to-delhi', 'delhi-to-aligarh', 'lucknow-to-allahabad',
       'lucknow-to-delhi', 'delhi-to-farrukhabad', 'farrukhabad-to-delhi',
       'badaun-to-delhi', 'allahabad-to-lucknow', 'lucknow-to-agra',
       'sitapur-to-delhi', 'delhi-to-badaun', 'delhi-to-sitapur',
       'agra-to-delhi', 'delhi-to-moradabad', 'delhi-to-lucknow',
       'agra-to-lucknow', 'lucknow-to-varanasi', 'agra-to-bareilly',
       'lucknow-to-bareilly', 'varanasi-to-lucknow', 'delhi-to-agra',
       'moradabad-to-delhi', 'kanpur-to-jhansi', 'delhi-to-shahjahanpur',
       'shahjahanpur-to-delhi', 'gorakhpur-to-lucknow',
       'kanpur-to-bareilly', 'delhi-to-pilibhit', 'lucknow-to-ballia',
       'delhi-to-etah', 'lucknow-to-gorakhpur', 'aligarh-to-agra',
       'pilibhit-to-delhi', 'bareilly-to-lucknow', 'delhi-to-dehradun',
       'lucknow-to-mathura', 'jhansi-to-kanpur', 'dehradun-to-bareilly',
       'etah-to-delhi', 'barasat-to-contai-kanthi', 'habra-to-digha',
       'digha-to-habra', 'midnapore-to-barasat', 'kolkata-to-bolpur',
       'kolkata-to-bakkhali', 'kolkata-to-purulia', 'kolkata-to-mayapur',
       'habra-to-durgapur', 'yamuna-nagar-to-chandigarh',
       'chandigarh-to-delhi', 'ludhiana-to-chandigarh',
       'chandigarh-to-yamuna-nagar', 'chandigarh-to-vrindavan',
       'chandigarh-to-pathankot', 'chandigarh-to-dehradun',
       'sujanpur-to-chandigarh', 'talwara-to-chandigarh',
       'vrindavan-to-chandigarh', 'chandigarh-to-shimla',
       'chandigarh-to-baijnath', 'chandigarh-to-amritsar',
       'chandigarh-to-haridwar', 'narnaul-to-chandigarh',
       'hisar-to-chandigarh', 'jawala-ji-to-chandigarh',
       'baijnath-to-chandigarh', 'chandigarh-to-rohtak',
       'chandigarh-to-rishikesh', 'chandigarh-to-jawala-ji',
       'chandigarh-to-jammu', 'chandigarh-to-ferozpur',
       'srinagar-to-jammu', 'jammu-to-chandigarh', 'delhi-to-srinagar',
       'jammu-to-srinagar', 'kishtwar-to-jammu', 'katra-to-jammu',
       'diphu-to-guwahati', 'dokmoka-to-guwahati', 'bokolia-to-guwahati',
       'langhin-to-guwahati', 'manja-to-guwahati', 'diphu-to-jagiroad',
       'gopalganj-to-delhi', 'patna-to-bettiah', 'patna-to-motihari',
       'motihari-to-delhi', 'patna-to-balmiki-nagar-bihar',
       'patna-to-purnea', 'patna-to-katihar', 'patna-to-ranchi',
       'patna-to-kathmandu', 'muzaffarpur-to-ranchi',
       'patna-to-hazaribagh', 'patna-to-raxaul', 'gra-to-motihari',
       'motihari-to-lucknow', 'patna-to-araria', 'patna-to-forbesganj',
       'patna-to-saharsa', 'darbhanga-to-lucknow', 'gopalganj-to-lucknow',
       'patiala-to-delhi', 'ludhiana-to-delhi', 'jalandhar-to-delhi',
       'ludhiana-to-delhi-airport', 'phagwara-to-delhi-airport',
       'phagwara-to-delhi', 'amritsar-to-delhi',
       'amritsar-to-delhi-airport', 'jalandhar-to-delhi-airport']

# %%
-- dp-time f-19 d-color f-bold

# %%
from selenium.webdriver.common.by import By
from selenium import webdriver
import requests
from bs4 import BeautifulSoup
import re
import time

Total_Time = []
for i in  From_To:
    a = i.lower()
    b = re.findall("\w+[a-zA-Z\s\-\d+]+",a)
    c = str(b[0]).replace(" ","-")
    url = f"https://www.redbus.in/bus-tickets/{c}"
    drive = webdriver.Chrome()
    drive.get(url)
    time.sleep(60)
    
    for j in drive.find_elements(By.XPATH, './/div[@class="dur l-color lh-24"]'):
        Total_Time.append(j.text)

# %%
len(Total_Time)
# Out:
# 496

# %%
from selenium import webdriver

# %%
url = "https://www.redbus.in/bus-tickets/khammam-to-hyderabad"

# %%
from selenium.webdriver.common.by import By

# %%
url = "https://www.redbus.in/bus-tickets/khammam-to-hyderabad"
drive = webdriver.Chrome()
drive.get(url)
time.sleep(60)

# %%
Total_Time = []
for i in drive.find_elements(By.XPATH, './/div[@class="dur l-color lh-24"]'):
    Total_Time.append(i.text)

# %%
len(Total_Time)
# Out:
# 27

# %%
-- dp-loc l-color w-wrap f-12 m-top-8
-- dp-loc l-color w-wrap f-12 m-top-42
-- dp-loc l-color w-wrap f-12 m-top-42
-- dp-loc l-color w-wrap f-12 m-top-42

--travels lh-24 f-bold d-color

# %%
dp-loc l-color w-wrap f-12 m-top-8

# %%
From = []
for i in drive.find_elements(By.XPATH, './/div[@class="column-three p-right-10 w-10 fl"]'):
    From.append(i.text.split()[1:2])

# %%
From
# Out:
# [['Beeramguda'],
#  ['Madhapur'],
#  ['Moula'],
#  ['Miyapur'],
#  ['ashok'],
#  ['Miyapur'],
#  ['Madhapur'],
#  ['Miyapur'],
#  ['Beeramguda'],
#  ['Gachibowli'],
#  ['Beeramguda'],
#  ['Bhel'],
#  ['Gandi'],
#  ['saketh'],
#  ['Beeramguda'],
#  ['BANDLAGUDA'],
#  ['Tarnaka'],
#  ['Beeramguda'],
#  ['Ameerpet'],
#  ['Bhel'],
#  ['Serilingampally'],
#  ['LB'],
#  ['Chanda'],
#  ['Panjagutta'],
#  ['Beeramguda'],
#  ['Malkajgiri'],
#  ['Beeramguda'],
#  ['Lakdikapul'],
#  ['Kukatpalli'],
#  ['Bhel'],
#  ['BANDLAGUDA'],
#  ['Bachupally'],
#  ['Bandlaguda'],
#  ['ilapur'],
#  ['Suchitra'],
#  ['Shapur'],
#  ['SR'],
#  ['Kukatpally'],
#  ['Madhapur'],
#  ['Gandi'],
#  ['Bhel'],
#  ['Ameerpet'],
#  ['Beeramguda'],
#  ['Beeramguda'],
#  ['Gachibowli'],
#  ['Miyapur'],
#  ['Kukatpally'],
#  ['Kukatpally'],
#  ['Beeramguda'],
#  ['ilapur'],
#  ['Bhel'],
#  ['Panjagutta'],
#  ['Ameerpet'],
#  ['Kukatpally'],
#  ['Lakdikapul'],
#  ['Gandi'],
#  ['Beeramguda'],
#  ['Serilingampally'],
# ...

# %%
-- bp-loc l-color w-wrap f-12 m-top-8
--

# %%
To = []
for i in drive.find_elements(By.XPATH, './/div[@class="bp-loc l-color w-wrap f-12 m-top-8"]'):
    To.append(i.text)

# %%
len(To)
# Out:
# 78

# %%
#To.insert(22,"Dilsukhnagar")

# %%
Price = []
for i in drive.find_elements(By.XPATH, './/div[@class="fare d-block"]'):
    Price.append(i.text.split()[-1])

# %%
len(Price)
# Out:
# 79

# %%
-- lh-18 rating rat-red 
-- lh-18 rating rat-green 
-- lh-18 rating rat-orange

# %%
Rating = []
for i in drive.find_elements(By.XPATH, f'.//div[@class="rating-sec lh-24"]'):
    Rating.append(i.text)

# %%
len(Rating)
# Out:
# 77

# %%
Bus_Name = []
for i in drive.find_elements(By.XPATH, './/div[@class="travels lh-24 f-bold d-color"]'):
    Bus_Name.append(i.text)

# %%
len(Bus_Name)
# Out:
# 79

# %%
Bus_Type = []
for i in drive.find_elements(By.XPATH, './/div[@class="bus-type f-12 m-top-16 l-color evBus"]'):
    Bus_Type.append(i.text)

# %%
len(Bus_Type)
# Out:
# 79

# %%
Bus_Type
# Out:
# ['A/C Seater / Sleeper (2+1)',
#  'Scania AC Multi Axle Sleeper (2+1)',
#  'Volvo Multi Axle A/C Sleeper I-Shift B11R (2+1)',
#  'A/C Sleeper (2+1)',
#  'NON A/C Seater/ Sleeper (2+1)',
#  'A/C Sleeper (2+1)',
#  'Volvo Multi-Axle A/C Sleeper (2+1)',
#  'A/C Sleeper (2+1)',
#  'Non A/C Seater / Sleeper (2+1)',
#  'Volvo Multi-Axle A/C Sleeper (2+1)',
#  'Non A/C Seater / Sleeper (2+1)',
#  'Non A/C Seater / Sleeper (2+1)',
#  'Non A/C Seater / Sleeper (2+1)',
#  'Non A/C Seater / Sleeper (2+1)',
#  'NON A/C Sleeper (2+1)',
#  'NON A/C Seater/ Sleeper (2+1)',
#  'NON A/C Sleeper (2+1)',
#  'NON A/C Sleeper (2+1)',
#  'Non A/C Seater / Sleeper (2+1)',
#  'Non A/C Seater / Sleeper (2+1)',
#  'NON A/C Sleeper (2+1)',
#  'A/C Sleeper (2+1)',
#  'A/C Sleeper (2+1)',
#  'A/C Sleeper (2+1)',
#  'Non A/C Seater / Sleeper (2+1)',
#  'Non A/C Seater / Sleeper (2+1)',
#  'Non A/C Seater / Sleeper (2+1)',
#  'A/C Sleeper (2+1)',
#  'Non A/C Seater / Sleeper (2+1)',
# ...

# %%
State = []
for i in range(27):
    State.append("TSRTC")

# %%
len(State)
# Out:
# 27

# %%
From_To = []
for i in range(27):
    From_To.append("khammam-to-hyderabad")

# %%
len(From_To)
# Out:
# 27

# %%
import pandas as pd

# %%
df = {"PickUp":From,
     "Drop":To,
      "Bus_Type":Bus_Type,
     "Total_Time":Total_Time,
     "Bus_Name":Bus_Name,
      "From_To":From_To,
     "Rating":Rating,
     "Price":Price,
     "State":State}

# %%
df1 = pd.DataFrame(df)

# %%
df1
# Out:
#       PickUp                 Drop                         Bus_Type  \
# 0    Khammam            Erragadda             NON A/C Seater (2+2)
# 1     KHAMAM             SR Nagar   Non A/C Seater / Sleeper (2+1)
# 2     KHAMAM             SR Nagar   Non A/C Seater / Sleeper (2+1)
# 3    Khammam  Lingampalli B H E L   Non A/C Seater / Sleeper (2+1)
# 4    Khammam              Miyapur   Non A/C Seater / Sleeper (2+1)
# 5    Khammam           Lakdikapul   Non A/C Seater / Sleeper (2+1)
# 6   Hospital           Beeramguda             NON A/C Seater (2+2)
# 7    Khammam              Chintal              Non AC Seater (2+2)
# 8    Khammam             Moosapet            NON A/C Hi-Tech (2+2)
# 9    Khammam             Moosapet            NON A/C Hi-Tech (2+2)
# 10   Khammam      Vanasthalipuram   Non A/C Seater / Sleeper (2+1)
# 11   Khammam             Moosapet       A/C Seater / Sleeper (2+1)
# 12    KHAMAM      Vanasthalipuram                A/C Sleeper (2+1)
# ...

# %%
df1.to_csv("Khammam.csv")

# %%
Price
# Out:
# []

# %%
-- travels lh-24 f-bold d-color
-- travels lh-24 f-bold d-color

-- //*[@id="29836006"]/div/div[1]/div[1]/div[1]/div[1]
-- //*[@id="28657115"]/div/div[1]/div[1]/div[1]/div[1]
travels lh-24 f-bold d-color

# %%
--bus-type f-12 m-top-16 l-color evBus
--bus-type f-12 m-top-16 l-color evBus

--//*[@id="28548287"]/div/div[1]/div[1]/div[1]/div[2]
--//*[@id="25579063"]/div/div[1]/div[1]/div[1]/div[2]

# %%
import pandas as pd

# %%
df1
# Out:
#      Unnamed: 0      PickUp           Drop  \
# 0             0  Gachibowli          Nagar
# 1             1  Kukatpally  Ibrahimpatnam
# 2             2  Kukatpally  Ibrahimpatnam
# 3             3  Gachibowli         Tenali
# 4             4     Miyapur  Ibrahimpatnam
# ..          ...         ...            ...
# 334         334  Kukatpally   Governorpeta
# 335         335  Kukatpally         Circle
# 336         336  Kukatpally   Governorpeta
# 337         337  Kukatpally         Circle
# 338         338  Beeramguda       BUSSTAND
#
#                                Bus_Type Total_Time                  Bus_Name  \
# 0            A/C Seater / Sleeper (2+1)      06 50         IntrCity SmartBus
# 1             Electric A/C Seater (2+2)      06 40                     NueGo
# 2             Electric A/C Seater (2+2)      06 15                  FRESHBUS
# 3            A/C Seater / Sleeper (2+1)      07 50       AdIntrCity SmartBus
# ...

# %%
df1["PickUp"].unique()
# Out:
# array(['Gachibowli', 'Kukatpally', 'Miyapur', 'Chanda', 'Hitec',
#        'Kothapet', 'Moosapet', 'BHEL', 'Malakpet', 'Choutuppal',
#        'Jeedimetla', 'Gandi', 'Beeramguda', 'Ecil', 'Ramachandra', 'LB',
#        'Suchitra', 'Lakdikapul', 'Bahadurpally', 'Erragadda',
#        'Patancheru', 'Sanathnagar', 'Chandanagar', 'Nizampet', 'Bharat',
#        'Hydernagar', 'SR', 'Kompally', 'Ameerpet', 'Suraram',
#        'Madhinaguda', 'Hafeezpet', 'Dulapally', 'Next', 'Bachupalli',
#        'Deepthi', 'Nampally', 'MANIKONDA', 'KPHB', 'Khairatabad',
#        'Kalakallu', 'Serilingampally', 'Central', 'Bhel'], dtype=object)

# %%
df1 = pd.read_csv(r"C:\Users\anees\Data Analysis\Python\Redbus\bus1.csv")
df2 = pd.read_csv(r"C:\Users\anees\Data Analysis\Python\Redbus\bus2.csv")
df3 = pd.read_csv(r"C:\Users\anees\Data Analysis\Python\Redbus\bus3.csv")
df4 = pd.read_csv(r"C:\Users\anees\Data Analysis\Python\Redbus\bus4.csv")
df5 = pd.read_csv(r"C:\Users\anees\Data Analysis\Python\Redbus\bus5.csv")
df6 = pd.read_csv(r"C:\Users\anees\Data Analysis\Python\Redbus\bus6.csv")
df7 = pd.read_csv(r"C:\Users\anees\Data Analysis\Python\Redbus\bus7.csv")
df8 = pd.read_csv(r"C:\Users\anees\Data Analysis\Python\Redbus\bus8.csv")
df9 = pd.read_csv(r"C:\Users\anees\Data Analysis\Python\Redbus\bus9.csv")
df10 = pd.read_csv(r"C:\Users\anees\Data Analysis\Python\Redbus\bus10.csv")
df11 = pd.read_csv(r"C:\Users\anees\Data Analysis\Python\Redbus\bus11.csv")
df12 = pd.read_csv(r"C:\Users\anees\Data Analysis\Python\Redbus\bus12.csv")
df13 = pd.read_csv(r"C:\Users\anees\Data Analysis\Python\Redbus\bus13.csv")
df14 = pd.read_csv(r"C:\Users\anees\Data Analysis\Python\Redbus\bus14.csv")
df15 = pd.read_csv(r"C:\Users\anees\Data Analysis\Python\Redbus\bus15.csv")
df16 = pd.read_csv(r"C:\Users\anees\Data Analysis\Python\Redbus\bus16.csv")
df17 = pd.read_csv(r"C:\Users\anees\Data Analysis\Python\Redbus\bus17.csv")
df18 =pd.read_csv(r"C:\Users\anees\Data Analysis\Python\Redbus\bus18.csv")
df19 = pd.read_csv(r"C:\Users\anees\Data Analysis\Python\Redbus\bus19.csv")
df20 = pd.read_csv(r"C:\Users\anees\Data Analysis\Python\Redbus\bus20.csv")
df21 =pd.read_csv(r"C:\Users\anees\Data Analysis\Python\Redbus\bus21.csv")
df22 = pd.read_csv(r"C:\Users\anees\Data Analysis\Python\Redbus\bus22.csv")
df23 = pd.read_csv(r"C:\Users\anees\Data Analysis\Python\Redbus\bus23.csv")

# %%
df = pd.concat([df23,df2,df3,df4,df5,df6,df7,df8,df9,df10,df11,df12,df13,df14,df15,df16,df17,df18,df19,df20,df21,df22,df1],axis = 0)

# %%
df = pd.concat([df10,df11],axis = 0)

# %%
df4
# Out:
#    Unnamed: 0                     PickUp          Drop  \
# 0           0    Jubilee Bus Station JBS  SRISAILAM BS
# 1           1  Central Bus Station (CBS)  SRISAILAM BS
# 2           2    Jubilee Bus Station JBS  SRISAILAM BS
# 3           3                       Bhel  SRISAILAM BS
# 4           4    Jubilee Bus Station JBS  SRISAILAM BS
# 5           5    Jubilee Bus Station JBS  SRISAILAM BS
# 6           6                       Bhel  SRISAILAM BS
# 7           7    Jubilee Bus Station JBS  SRISAILAM BS
# 8           8                 Kukatpally  SRISAILAM BS
#
#                                      Bus_Type Total_Time      Bus_Name  \
# 0  Super Luxury (Non AC Seater 2+2 Push Back)      07 15  TSRTC - 1266
# 1                  Deluxe (Non AC Seater 2+2)      06 15  TSRTC - 1964
# 2  Super Luxury (Non AC Seater 2+2 Push Back)      12 15  TSRTC - 4322
# 3  Super Luxury (Non AC Seater 2+2 Push Back)      12 20  TSRTC - 1254
# ...

# %%
df9["Bus_Type"].unique()
# Out:
# array(['Volvo Multi-Axle A/C Semi Sleeper (2+2)', 'A/C Sleeper (2+1)',
#        'NON A/C Sleeper (2+1)', 'Bharat Benz A/C Seater (2+2)',
#        'Non AC Seater (2+2)', 'Non A/C Seater / Sleeper (2+1)',
#        'NON A/C Semi Sleeper (2+2)', 'Scania AC Multi Axle Sleeper (2+1)',
#        'NON A/C Airbus (2+2)', 'AC Sleeper (2+1)',
#        'Bharat Benz A/C Sleeper (2+1)', 'NON A/C Seater (2+2)',
#        'A/C Seater / Sleeper (2+1)',
#        'Volvo 9600 Multi-Axle A/C Sleeper (2+1)',
#        'Volvo Multi Axle Sleeper B11R (2+1)', 'NON A/C Seater (2+1)'],
#       dtype=object)

# %%
df9["Drop"].unique()
# Out:
# array(['Adilabad office', 'Sahara Office', 'Khairatabad', 'New Bus Stand',
#        'Opp Adb Bus Stop Raj Travels', 'Metro Office', 'Adilabad',
#        'MAVALA VILLAGE', 'RTC Bus Stand', 'Bus stand adilabad',
#        'Bus stand', 'adilabad', 'Adilabad Bypass'], dtype=object)

# %%
df9["PickUp"].unique()
# Out:
# array(['JBS -Centenary High school (P...', 'Putlibowli',
#        'Jubilee Bus Station JBS', 'Namapally', 'Paradise', 'Chanda Nagar',
#        'Bowenpally', 'Nampally', 'Lakdikapul', 'Kompally',
#        'Nampally near limra travels', 'Balamrai', 'Tolichowki',
#        'Central Bus Station (CBS)', 'Miyapur', 'SR Nagar'], dtype=object)

# %%
df9["Rating"].unique()
# Out:
# array(['3.5', '3.6', '3.4', '3.3', '4.4', '3.7', '3.8', '4.2', '2.5',
#        '1.9', '3.2', '2.6', '2.8', '1.7', '2.0', '2.1', '3.9', '1.5',
#        '2.7', '2.2', '2.3', 'Nan'], dtype=object)

# %%
df.drop("Unnamed: 0",axis = 1,inplace = True)

# %%
df
# Out:
#            PickUp                Drop                            Bus_Type  \
# 0      Bala Nagar       Bommalasatram      Non A/C Seater / Sleeper (2+1)
# 1    Chanda Nagar       RTC Bus Stand         NON AC Seater / Sleeper 2+1
# 2    Chanda Nagar            Nandyala                   A/C Sleeper (2+1)
# 3        Malakpet  noonepalli flyover      Non A/C Seater / Sleeper (2+1)
# 4        LB Nagar  noonepalli flyover                   A/C Sleeper (2+1)
# ..            ...                 ...                                 ...
# 334    Kukatpally        Governorpeta                   A/C Sleeper (2+1)
# 335    Kukatpally              Circle      Non A/C Seater / Sleeper (2+1)
# 336    Kukatpally        Governorpeta          A/C Seater / Sleeper (2+1)
# 337    Kukatpally              Circle  Volvo Multi-Axle A/C Sleeper (2+1)
# 338    Beeramguda            BUSSTAND          A/C Seater / Sleeper (2+1)
#
#     Total_Time                  Bus_Name                  From_To Rating  \
# ...

# %%
df1 = pd.read_csv(r"C:\Users\anees\Data Analysis\Python\Redbus\AP1.csv")
df2 = pd.read_csv(r"C:\Users\anees\Data Analysis\Python\Redbus\AP2.csv")
df3 = pd.read_csv(r"C:\Users\anees\Data Analysis\Python\Redbus\AP3.csv")
df4 = pd.read_csv(r"C:\Users\anees\Data Analysis\Python\Redbus\AP4.csv")
df5 = pd.read_csv(r"C:\Users\anees\Data Analysis\Python\Redbus\AP5.csv")
df6 = pd.read_csv(r"C:\Users\anees\Data Analysis\Python\Redbus\Ap6.csv")
df7 = pd.read_csv(r"C:\Users\anees\Data Analysis\Python\Redbus\AP7.csv")
df8 = pd.read_csv(r"C:\Users\anees\Data Analysis\Python\Redbus\AP8.csv")
df9 = pd.read_csv(r"C:\Users\anees\Data Analysis\Python\Redbus\AP9.csv")
df10 = pd.read_csv(r"C:\Users\anees\Data Analysis\Python\Redbus\AP10.csv")
df11 = pd.read_csv(r"C:\Users\anees\Data Analysis\Python\Redbus\AP11.csv")
df12 = pd.read_csv(r"C:\Users\anees\Data Analysis\Python\Redbus\AP12.csv")
df13 = pd.read_csv(r"C:\Users\anees\Data Analysis\Python\Redbus\AP13.csv")
df14 = pd.read_csv(r"C:\Users\anees\Data Analysis\Python\Redbus\AP14.csv")
df15 = pd.read_csv(r"C:\Users\anees\Data Analysis\Python\Redbus\AP15.csv")
df16 = pd.read_csv(r"C:\Users\anees\Data Analysis\Python\Redbus\AP16.csv")
df17 = pd.read_csv(r"C:\Users\anees\Data Analysis\Python\Redbus\AP17.csv")
df18 =pd.read_csv(r"C:\Users\anees\Data Analysis\Python\Redbus\AP18.csv")
df19 = pd.read_csv(r"C:\Users\anees\Data Analysis\Python\Redbus\AP19.csv")
df20 = pd.read_csv(r"C:\Users\anees\Data Analysis\Python\Redbus\AP20.csv")
df21 =pd.read_csv(r"C:\Users\anees\Data Analysis\Python\Redbus\AP21.csv")
df22 = pd.read_csv(r"C:\Users\anees\Data Analysis\Python\Redbus\AP22.csv")
df23 = pd.read_csv(r"C:\Users\anees\Data Analysis\Python\Redbus\AP23.csv")
df24 = pd.read_csv(r"C:\Users\anees\Data Analysis\Python\Redbus\AP24.csv")
df25 = pd.read_csv(r"C:\Users\anees\Data Analysis\Python\Redbus\AP25.csv")
df26= pd.read_csv(r"C:\Users\anees\Data Analysis\Python\Redbus\AP26.csv")
df27 = pd.read_csv(r"C:\Users\anees\Data Analysis\Python\Redbus\AP27.csv")
df28 = pd.read_csv(r"C:\Users\anees\Data Analysis\Python\Redbus\AP28.csv")
df29 = pd.read_csv(r"C:\Users\anees\Data Analysis\Python\Redbus\Ap29.csv")
df30 = pd.read_csv(r"C:\Users\anees\Data Analysis\Python\Redbus\AP30.csv")
df31 = pd.read_csv(r"C:\Users\anees\Data Analysis\Python\Redbus\AP31.csv")
df32 = pd.read_csv(r"C:\Users\anees\Data Analysis\Python\Redbus\AP32.csv")
df33 = pd.read_csv(r"C:\Users\anees\Data Analysis\Python\Redbus\AP33.csv")
df34 = pd.read_csv(r"C:\Users\anees\Data Analysis\Python\Redbus\AP34.csv")
df35 = pd.read_csv(r"C:\Users\anees\Data Analysis\Python\Redbus\AP35.csv")
df36 = pd.read_csv(r"C:\Users\anees\Data Analysis\Python\Redbus\AP36.csv")
df37 = pd.read_csv(r"C:\Users\anees\Data Analysis\Python\Redbus\AP37.csv")
df38 = pd.read_csv(r"C:\Users\anees\Data Analysis\Python\Redbus\AP38.csv")
df39 = pd.read_csv(r"C:\Users\anees\Data Analysis\Python\Redbus\AP39.csv")
df40 = pd.read_csv(r"C:\Users\anees\Data Analysis\Python\Redbus\AP40.csv")
df41 =pd.read_csv(r"C:\Users\anees\Data Analysis\Python\Redbus\AP41.csv")
df42 = pd.read_csv(r"C:\Users\anees\Data Analysis\Python\Redbus\AP42.csv")
df43 = pd.read_csv(r"C:\Users\anees\Data Analysis\Python\Redbus\AP43.csv")
df44 =pd.read_csv(r"C:\Users\anees\Data Analysis\Python\Redbus\AP44.csv")

# %%
DF = pd.concat([df1,df2,df3,df4,df5,df6,df7,df8,df9,df10,df11,df12,df13,df14,df15,df16,df17,df18,df19,df20,df21,df22,df23,df24,df25,df26,df27,df28,df29,df30,df31,df32,df33,df34,df35,df36,df37,df38,df39,df40,df41,df42,df43,df44],axis = 0)

# %%
DF
# Out:
#     Unnamed: 0        PickUp           Drop  \
# 0            0      Kondapur    Benz Circle
# 1            1       Miyapur  Ibrahimpatnam
# 2            2  Chanda Nagar    Benz Circle
# 3            3      Kondapur    Benz Circle
# 4            4  Chanda Nagar    Benz Circle
# ..         ...           ...            ...
# 87          87  Chanda Nagar       Nandyala
# 88          88      Moosapet       Nandyala
# 89          89      Moosapet       Nandyala
# 90          90    Hydernagar       Nandyala
# 91          91       Miyapur        Nandyal
#
#                                   Bus_Type Total_Time    Bus_Name  \
# 0               A/C Seater / Sleeper (2+1)      06 50    IntrCity
# 1                Electric A/C Seater (2+2)      07 05       NueGo
# 2                Electric A/C Seater (2+2)      07 15    FRESHBUS
# 3               A/C Seater / Sleeper (2+1)      07 10  AdIntrCity
# 4                Electric A/C Seater (2+2)      06 55    FRESHBUS
# ...

# %%
DF["PickUp"].unique()
# Out:
# array(['Kondapur', 'Miyapur', 'Chanda Nagar', 'Beeramguda',
#        'Sri Nagar Colony', 'Bhel', 'Serilingampally', 'Hafeezpet',
#        'Bachupally', 'LB Nagar', 'Choutuppal', 'Ramachandra Puram',
#        'Ecil', 'Bolarum', 'Suraram', 'Nizampet', 'Secunderabad',
#        'Gachibowli', 'Gandi Maisamma', 'Kukatpally', 'Bahadurpally',
#        'Patancheru', 'Medchal', 'SR Nagar', 'Malakpet', 'Moosapet',
#        'Bharat Nagar', 'Vanasthalipuram', 'Suchitra',
#        'BHEL (Pickup Van/Bus)', 'Hydernagar', 'Dilsukhnagar',
#        'Jeedimetla', 'IDPL', 'Gandimaisamma', 'Malkajgiri', 'Dundigal',
#        'Beeramguda (Pickup Van/Bus)', 'Gachibowli (Pickup Van/Bus)',
#        'Chintal', 'Ramoji Film City', 'Bachupalli', 'Madhapur', 'K.P.H.B',
#        'Balanagar', 'Beeramgud', 'B.H.E.L (Pickup Van/Bus)', 'Chityal',
#        'chityala', 'Isnapur', 'Ganguru', 'Mangalgiri Bypass',
#        'Sithara Center', 'Poranki', 'Rtc bus stand', 'Benz Circle',
# ...

# %%
DF.drop("Unnamed: 0",axis = 1,inplace = True)

# %%
dff = pd.concat([df,DF],axis = 0)

# %%
dff
# Out:
#           PickUp                Drop                                Bus_Type  \
# 0     Bala Nagar       Bommalasatram          Non A/C Seater / Sleeper (2+1)
# 1   Chanda Nagar       RTC Bus Stand             NON AC Seater / Sleeper 2+1
# 2   Chanda Nagar            Nandyala                       A/C Sleeper (2+1)
# 3       Malakpet  noonepalli flyover          Non A/C Seater / Sleeper (2+1)
# 4       LB Nagar  noonepalli flyover                       A/C Sleeper (2+1)
# ..           ...                 ...                                     ...
# 87  Chanda Nagar            Nandyala                       A/C Sleeper (2+1)
# 88      Moosapet            Nandyala                       A/C Sleeper (2+1)
# 89      Moosapet            Nandyala           Bharat Benz A/C Sleeper (2+1)
# 90    Hydernagar            Nandyala                       A/C Sleeper (2+1)
# 91       Miyapur             Nandyal  Volvo Multi Axle B9R A/C Sleeper (2+1)
#
# ...

# %%
df1 = pd.read_csv(r"C:\Users\anees\Data Analysis\Python\Redbus\GOA1.csv")
df2 = pd.read_csv(r"C:\Users\anees\Data Analysis\Python\Redbus\GOA2.csv")
df3 = pd.read_csv(r"C:\Users\anees\Data Analysis\Python\Redbus\GOA3.csv")
df4 = pd.read_csv(r"C:\Users\anees\Data Analysis\Python\Redbus\GOA4.csv")
df5 = pd.read_csv(r"C:\Users\anees\Data Analysis\Python\Redbus\GOA5.csv")
df6 = pd.read_csv(r"C:\Users\anees\Data Analysis\Python\Redbus\GOA6.csv")
df7 = pd.read_csv(r"C:\Users\anees\Data Analysis\Python\Redbus\GOA7.csv")
df8 = pd.read_csv(r"C:\Users\anees\Data Analysis\Python\Redbus\GOA8.csv")
#df9 = pd.read_csv(r"C:\Users\anees\Data Analysis\Python\Redbus\GOA9.csv")
df10 = pd.read_csv(r"C:\Users\anees\Data Analysis\Python\Redbus\GOA10.csv")
df11 = pd.read_csv(r"C:\Users\anees\Data Analysis\Python\Redbus\GOA11.csv")
df12 = pd.read_csv(r"C:\Users\anees\Data Analysis\Python\Redbus\GOA12.csv")
df13 = pd.read_csv(r"C:\Users\anees\Data Analysis\Python\Redbus\GOA13.csv")
df14 = pd.read_csv(r"C:\Users\anees\Data Analysis\Python\Redbus\GOA14.csv")
df15 = pd.read_csv(r"C:\Users\anees\Data Analysis\Python\Redbus\GOA15.csv")
df16 = pd.read_csv(r"C:\Users\anees\Data Analysis\Python\Redbus\GOA16.csv")
df17 = pd.read_csv(r"C:\Users\anees\Data Analysis\Python\Redbus\GOA17.csv")
df18 =pd.read_csv(r"C:\Users\anees\Data Analysis\Python\Redbus\GOA18.csv")

# %%
DFF = pd.concat([df1,df2,df3,df4,df5,df6,df7,df8,df10,df11,df12,df13,df14,df15,df16,df17,df18],axis=0)

# %%
DFF
# Out:
#     Unnamed: 0                         PickUp      Drop  \
# 0            0                Railway Station   Madgaon
# 1            1                       Swargate  Porvorim
# 2            2                       Swargate  Porvorim
# 3            3                       Swargate    Mapusa
# 4            4                       Swargate    Mapusa
# ..         ...                            ...       ...
# 9            9  Manohar International Airport    Panjim
# 10          10  Manohar International Airport    Mapusa
# 11          11  Manohar International Airport    Mapusa
# 12          12  Manohar International Airport    Margoa
# 13          13  Manohar International Airport    Mapusa
#
#                          Bus_Type Total_Time    Bus_Name              From_To  \
# 0               Non AC Seater 2+2      12 00     Kadamba          pune-to-goa
# 1            VE A/C Sleeper (2+1)      10 45     Atmaram          pune-to-goa
# ...

# %%
DFF.drop("Unnamed: 0",axis = 1,inplace = True)

# %%
DFF
# Out:
#                            PickUp      Drop                       Bus_Type  \
# 0                 Railway Station   Madgaon              Non AC Seater 2+2
# 1                        Swargate  Porvorim           VE A/C Sleeper (2+1)
# 2                        Swargate  Porvorim           VE A/C Sleeper (2+1)
# 3                        Swargate    Mapusa  Bharat Benz A/C Sleeper (2+1)
# 4                        Swargate    Mapusa              A/C Sleeper (2+1)
# ..                            ...       ...                            ...
# 9   Manohar International Airport    Panjim               A/C Seater (2+3)
# 10  Manohar International Airport    Mapusa               A/C Seater (2+3)
# 11  Manohar International Airport    Mapusa               A/C Seater (2+3)
# 12  Manohar International Airport    Margoa               A/C Seater (2+3)
# 13  Manohar International Airport    Mapusa               A/C Seater (2+3)
#
#    Total_Time    Bus_Name              From_To Rating  Price State
# ...

# %%
DFF["PickUp"].unique()
# Out:
# array(['Railway Station', 'Swargate', 'Padmavati Parking', 'Wakad',
#        'Katraj', 'Tale Gaon', 'Shivaji Nagar', 'Kharadi', 'Hinje Wadi',
#        'Talegaon Toll Plaza', 'Wadgaon Bridge', 'Mapusa', 'Madgaon',
#        'Pernem', 'Panjim', 'Zarap - Zarap Tita, Before Fl...', 'Porvorim',
#        'Margao Opp ktc Bus Stand', 'Kankavli', '(A)Mapus- Taj Travels',
#        'Taj Travels', 'Mapusa New Interstate Bus Sta...', 'Borivali West',
#        'Sion', 'Borivali East', 'Malad East',
#        'Gujarat travels,mauli hotel,v...', 'Andheri East',
#        'Market Vt (Pickup Van)', 'Majestic', 'Anand Rao Circle',
#        'Majestic Anandrao Circle', 'Race Course Road Paulo Travel...',
#        'Kalasipalyam', 'Jaya Nagar', 'Margoa Kadamba Bus Stand',
#        'Interstate Private Bus Parkin...', 'Aluva Paravoor Kavala',
#        'Mapsa', 'Kudal', 'Banda - S.T. Bus Stand',
#        'Mapusa - IntrCity Lounge', 'Banda - ST Stand', 'Kudal ST Stand',
# ...

# %%
DFF["From_To"].unique()
# Out:
# array(['pune-to-goa', 'goa-to-pune', 'mumbai-to-goa', 'bangalore-to-goa',
#        'goa-to-bangalore', 'goa-to-mumbai', 'goa-to-kolhapur',
#        'pandharpur-to-goa', 'solapur-to-goa', 'goa-to-solapur',
#        'goa-to-sangli', 'goa-to-sangola', 'sangola-to-goa',
#        'goa-to-miraj', 'goa-to-mopa-airport', 'panaji-to-goa-airport',
#        'mopa-airport-to-goa'], dtype=object)

# %%
DFF["Drop"].unique()
# Out:
# array(['Madgaon', 'Porvorim', 'Mapusa', 'Pernem', 'Panjim', 'HT', 'Malpe',
#        'Kankavli', 'Katraj', 'Nigdi', 'Padmavati Parking', 'Satara',
#        'Wakad', 'Swargate', 'Hinje Wadi', 'Tale Gaon', 'Kharadi',
#        ' GPS location Ferguss', 'Shivaji Nagar', ' Pune', 'Bhumkar Chowk',
#        'Wadgaon Bridge', 'Talegaon', 'Navle Bridge', 'Lonavala By Pass',
#        'Swargate Laxminarayan Theatre', 'Satarda',
#        'Pernem Malpem Petrol Pump', ' panjim', 'Canacona',
#        'Margoa Kadamba Bus Stand', 'Mapsa',
#        'Cuncolim Paulo Travels New Bus', 'Majestic', 'Anand Rao Circle',
#        'Yeshwantpur', 'Nelamangala', 'Nelamangala Toll', ' th mail',
#        'Sion', 'Kalamboli', 'Borivali East', 'Kharghar', 'Goregaon East',
#        'Nerul', 'Mankrud Highway', 'Wadi Bunder Kalyan Street Nea',
#        'Fort CST Railway Station', 'Jogeshwari', 'Panvel',
#        'Dabholkar Corner', 'Bus Stand', 'Ayodhya hotel tararani chowk',
# ...

# %%
DFF["Bus_Type"].unique()
# Out:
# array(['Non AC Seater 2+2', 'VE A/C Sleeper (2+1)',
#        'Bharat Benz A/C Sleeper (2+1)', 'A/C Sleeper (2+1)',
#        'Volvo Multi-Axle A/C Sleeper (2+1)', 'NON A/C Sleeper (1+2)',
#        'AC Sleeper (2+1)', 'NON A/C Sleeper (2+1)',
#        'Bharat Benz A/C Seater /Sleeper (2+1)',
#        'Non A/C Seater / Sleeper (2+1)',
#        'Volvo Multi-Axle I-Shift A/C Sleeper (2+1)',
#        'Volvo A/C Sleeper (2+1)', 'NON A/C Seater/ Sleeper (2+1)',
#        'Non AC Seater (2+2)', 'A/C Seater (2+2)',
#        'NON A/C Seater Push Back (2+2)', 'A/C Seater Push Back (2+2)',
#        'Volvo Multi Axle A/C Sleeper I-Shift B11R (2+1)',
#        'NON A/C Airbus (2+2)', 'Volvo Multi-Axle Sleeper A/C (2+1)',
#        'NON A/C Seater (2+2)', 'Volvo 9600 Multi-Axle A/C Sleeper (2+1)',
#        'Volvo AC Seater Pushback 2+2', 'Mercedes Benz A/C Sleeper (2+1)',
#        'Volvo AC Seater 2+2', 'NON AC Seater / Sleeper 2+1',
#        'Volvo Multi-Axle I-Shift B11R Semi Sleeper (2+2)',
# ...

# %%
DFF["Rating"].unique()
# Out:
# array(['4.1', '4.6', '4.5', '4.2', '4.4', '4.3', '4.0', '3.9', '3.8',
#        '3.7', '3.6', '3.4', '3.2', '3.3', '3.0', '3.5', '2.7', '2.3',
#        '1.9', '2.0', '1.2', '1.1', '3.1', 'Nan', '4.7', '4.9', '2.6',
#        '2.5', '2.2', '2.9', '2.8', 3.7, 4.5, 4.4, 4.0, 4.3, 4.1, 3.5, 3.6,
#        3.3, 3.2, 1.0, 2.4, 3.4, 2.8, 2.1, 2.3, 3.1, 2.5, 3.0, 3.9, 2.9,
#        1.3, 3.8, '1.3', '2.1', '2.4', 4.9, 1.8, 2.6, 2.2, 4.8, 4.2, 2.0,
#        1.9, 2.7, 5.0], dtype=object)

# %%
dff1 = pd.concat([dff,DFF],axis = 0)

# %%
dff1
# Out:
#                            PickUp                Drop  \
# 0                      Bala Nagar       Bommalasatram
# 1                    Chanda Nagar       RTC Bus Stand
# 2                    Chanda Nagar            Nandyala
# 3                        Malakpet  noonepalli flyover
# 4                        LB Nagar  noonepalli flyover
# ..                            ...                 ...
# 9   Manohar International Airport              Panjim
# 10  Manohar International Airport              Mapusa
# 11  Manohar International Airport              Mapusa
# 12  Manohar International Airport              Margoa
# 13  Manohar International Airport              Mapusa
#
#                           Bus_Type Total_Time Bus_Name                From_To  \
# 0   Non A/C Seater / Sleeper (2+1)      06 30     Indu  hyderabad-to-nandyala
# 1      NON AC Seater / Sleeper 2+1      06 50      BRS  hyderabad-to-nandyala
# 2                A/C Sleeper (2+1)      07 15      BRS  hyderabad-to-nandyala
# ...

# %%
df1 = pd.read_csv(r"C:\Users\anees\Data Analysis\Python\Redbus\KA1.csv")
df2 = pd.read_csv(r"C:\Users\anees\Data Analysis\Python\Redbus\KA2.csv")
df3 = pd.read_csv(r"C:\Users\anees\Data Analysis\Python\Redbus\KA3.csv")
df4 = pd.read_csv(r"C:\Users\anees\Data Analysis\Python\Redbus\KA4.csv")
df5 = pd.read_csv(r"C:\Users\anees\Data Analysis\Python\Redbus\KA5.csv")
df6 = pd.read_csv(r"C:\Users\anees\Data Analysis\Python\Redbus\KA6.csv")
df7 = pd.read_csv(r"C:\Users\anees\Data Analysis\Python\Redbus\KA7.csv")
df8 = pd.read_csv(r"C:\Users\anees\Data Analysis\Python\Redbus\KA8.csv")
df9 = pd.read_csv(r"C:\Users\anees\Data Analysis\Python\Redbus\KA9.csv")
df10 = pd.read_csv(r"C:\Users\anees\Data Analysis\Python\Redbus\KA10.csv")
df11 = pd.read_csv(r"C:\Users\anees\Data Analysis\Python\Redbus\KA11.csv")
df12 = pd.read_csv(r"C:\Users\anees\Data Analysis\Python\Redbus\KA12.csv")
df13 = pd.read_csv(r"C:\Users\anees\Data Analysis\Python\Redbus\KA13.csv")
df14 = pd.read_csv(r"C:\Users\anees\Data Analysis\Python\Redbus\KA14.csv")
df15 = pd.read_csv(r"C:\Users\anees\Data Analysis\Python\Redbus\KA15.csv")

# %%
DFF1 = pd.concat([df1,df2,df3,df4,df5,df6,df7,df8,df10,df11,df12,df13,df14,df15],axis=0)

# %%
DFF1
# Out:
#     Unnamed: 0                           PickUp                     Drop  \
# 0            0              Satellite Bus Stand                Kozhikode
# 1            1                         Madiwala                  Calicut
# 2            2                     Kalasipalyam                  Calicut
# 3            3                     Kalasipalyam                  Calicut
# 4            4  Shettihalli Cross (Pickup Va...                Kozhikode
# ..         ...                              ...                      ...
# 3            3                   Baker Junction            New Bus Stand
# 4            4                         Kottayam                  Calicut
# 5            5                       Nagampadam                Kozhikode
# 6            6             Nagampadam Bus Stand  Kozhikode Pvt Bus Stand
# 7            7                         Kottayam                Kozhikode
#
#                               Bus_Type Total_Time Bus_Name  \
# ...

# %%
DFF1.drop("Unnamed: 0",axis = 1,inplace = True)

# %%
dff2 = pd.concat([dff1,DFF1],axis = 0)

# %%
dff2
# Out:
#                   PickUp                     Drop  \
# 0             Bala Nagar            Bommalasatram
# 1           Chanda Nagar            RTC Bus Stand
# 2           Chanda Nagar                 Nandyala
# 3               Malakpet       noonepalli flyover
# 4               LB Nagar       noonepalli flyover
# ..                   ...                      ...
# 3         Baker Junction            New Bus Stand
# 4               Kottayam                  Calicut
# 5             Nagampadam                Kozhikode
# 6   Nagampadam Bus Stand  Kozhikode Pvt Bus Stand
# 7               Kottayam                Kozhikode
#
#                               Bus_Type Total_Time Bus_Name  \
# 0       Non A/C Seater / Sleeper (2+1)      06 30     Indu
# 1          NON AC Seater / Sleeper 2+1      06 50      BRS
# 2                    A/C Sleeper (2+1)      07 15      BRS
# 3       Non A/C Seater / Sleeper (2+1)      06 35     Indu
# 4                    A/C Sleeper (2+1)      06 25     Indu
# ...

# %%
df1 = pd.read_csv(r"C:\Users\anees\Data Analysis\Python\Redbus\RJ1.csv")
df2 = pd.read_csv(r"C:\Users\anees\Data Analysis\Python\Redbus\RJ2.csv")
df3 = pd.read_csv(r"C:\Users\anees\Data Analysis\Python\Redbus\RJ3.csv")
df4 = pd.read_csv(r"C:\Users\anees\Data Analysis\Python\Redbus\RJ4.csv")
df5 = pd.read_csv(r"C:\Users\anees\Data Analysis\Python\Redbus\RJ5.csv")
df6 = pd.read_csv(r"C:\Users\anees\Data Analysis\Python\Redbus\RJ6.csv")
#df7 = pd.read_csv(r"C:\Users\anees\Data Analysis\Python\Redbus\RJ7.csv")
df8 = pd.read_csv(r"C:\Users\anees\Data Analysis\Python\Redbus\RJ8.csv")
df9 = pd.read_csv(r"C:\Users\anees\Data Analysis\Python\Redbus\RJ9.csv")
df10 = pd.read_csv(r"C:\Users\anees\Data Analysis\Python\Redbus\RJ10.csv")
df11 = pd.read_csv(r"C:\Users\anees\Data Analysis\Python\Redbus\RJ11.csv")
df12 = pd.read_csv(r"C:\Users\anees\Data Analysis\Python\Redbus\RJ12.csv")
df13 = pd.read_csv(r"C:\Users\anees\Data Analysis\Python\Redbus\RJ13.csv")
df14 = pd.read_csv(r"C:\Users\anees\Data Analysis\Python\Redbus\RJ14.csv")
df15 = pd.read_csv(r"C:\Users\anees\Data Analysis\Python\Redbus\RJ15.csv")
df16 = pd.read_csv(r"C:\Users\anees\Data Analysis\Python\Redbus\RJ16.csv")
df17 = pd.read_csv(r"C:\Users\anees\Data Analysis\Python\Redbus\RJ17.csv")

# %%
DFF2 = pd.concat([df1,df2,df3,df4,df5,df6,df16,df8,df10,df11,df12,df13,df14,df15,df17],axis=0)

# %%
DFF2
# Out:
#     Unnamed: 0                            PickUp  \
# 0            0                    BHUWANA CIRCLE
# 1            1                          Udiapole
# 2            2                      Paras Circle
# 3            3                    BHUWANA CIRCLE
# 4            4  Jain travels, below hotel rel...
# ..         ...                               ...
# 54          54                     Ajmeri Puliya
# 55          55  Shiv Mahima Travels ajmeri Pu...
# 56          56                       Sindhi Camp
# 57          57                       Sindhi Camp
# 58          58                       Sindhi Camp
#
#                              Drop  \
# 0                        near cam
# 1                JHALAMAND CIRCLE
# 2                JHALAMAND CIRCLE
# 3   shree devnarayan travells Jha
# 4                 Shatabdi Circle
# ..                            ...
# 54        Near Nayapura Bus stand
# 55              Nayapura chauraha
# 56           M R Travels Nayapura
# ...

# %%
DFF2.drop("Unnamed: 0",axis = 1,inplace = True)

# %%
dff3 = pd.concat([dff2,DFF2],axis = 0)

# %%
dff3
# Out:
#                               PickUp                     Drop  \
# 0                         Bala Nagar            Bommalasatram
# 1                       Chanda Nagar            RTC Bus Stand
# 2                       Chanda Nagar                 Nandyala
# 3                           Malakpet       noonepalli flyover
# 4                           LB Nagar       noonepalli flyover
# ..                               ...                      ...
# 54                     Ajmeri Puliya  Near Nayapura Bus stand
# 55  Shiv Mahima Travels ajmeri Pu...        Nayapura chauraha
# 56                       Sindhi Camp     M R Travels Nayapura
# 57                       Sindhi Camp     M R Travels Nayapura
# 58                       Sindhi Camp     M R Travels Nayapura
#
#                           Bus_Type Total_Time Bus_Name                From_To  \
# 0   Non A/C Seater / Sleeper (2+1)      06 30     Indu  hyderabad-to-nandyala
# ...

# %%
import pandas as pd

# %%
#dff3.to_csv("table1.csv")

# %%
df = pd.read_csv(r"C:\Users\anees\Data Analysis\Python\Redbus\table1.csv")

# %%
df
# Out:
#       Unnamed: 0                            PickUp                     Drop  \
# 0              0                        Bala Nagar            Bommalasatram
# 1              1                      Chanda Nagar            RTC Bus Stand
# 2              2                      Chanda Nagar                 Nandyala
# 3              3                          Malakpet       noonepalli flyover
# 4              4                          LB Nagar       noonepalli flyover
# ...          ...                               ...                      ...
# 5613          54                     Ajmeri Puliya  Near Nayapura Bus stand
# 5614          55  Shiv Mahima Travels ajmeri Pu...        Nayapura chauraha
# 5615          56                       Sindhi Camp     M R Travels Nayapura
# 5616          57                       Sindhi Camp     M R Travels Nayapura
# 5617          58                       Sindhi Camp     M R Travels Nayapura
#
# ...

# %%
df.drop("Unnamed: 0",axis = 1,inplace = True)

# %%
df
# Out:
#                                 PickUp                     Drop  \
# 0                           Bala Nagar            Bommalasatram
# 1                         Chanda Nagar            RTC Bus Stand
# 2                         Chanda Nagar                 Nandyala
# 3                             Malakpet       noonepalli flyover
# 4                             LB Nagar       noonepalli flyover
# ...                                ...                      ...
# 5613                     Ajmeri Puliya  Near Nayapura Bus stand
# 5614  Shiv Mahima Travels ajmeri Pu...        Nayapura chauraha
# 5615                       Sindhi Camp     M R Travels Nayapura
# 5616                       Sindhi Camp     M R Travels Nayapura
# 5617                       Sindhi Camp     M R Travels Nayapura
#
#                             Bus_Type Total_Time Bus_Name  \
# 0     Non A/C Seater / Sleeper (2+1)      06 30     Indu
# 1        NON AC Seater / Sleeper 2+1      06 50      BRS
# ...

# %%
df1 = pd.read_csv(r"C:\Users\anees\Data Analysis\Python\Redbus\BA1.csv")
df2 = pd.read_csv(r"C:\Users\anees\Data Analysis\Python\Redbus\BA2.csv")
df3 = pd.read_csv(r"C:\Users\anees\Data Analysis\Python\Redbus\BA3.csv")
df4 = pd.read_csv(r"C:\Users\anees\Data Analysis\Python\Redbus\BA4.csv")
df5 = pd.read_csv(r"C:\Users\anees\Data Analysis\Python\Redbus\BA5.csv")
df6 = pd.read_csv(r"C:\Users\anees\Data Analysis\Python\Redbus\BA6.csv")
df7 = pd.read_csv(r"C:\Users\anees\Data Analysis\Python\Redbus\BA7.csv")
df8 = pd.read_csv(r"C:\Users\anees\Data Analysis\Python\Redbus\BA8.csv")
df9 = pd.read_csv(r"C:\Users\anees\Data Analysis\Python\Redbus\BA9.csv")
df10 = pd.read_csv(r"C:\Users\anees\Data Analysis\Python\Redbus\BA10.csv")
df11 = pd.read_csv(r"C:\Users\anees\Data Analysis\Python\Redbus\BA11.csv")
df12 = pd.read_csv(r"C:\Users\anees\Data Analysis\Python\Redbus\BA12.csv")
df13 = pd.read_csv(r"C:\Users\anees\Data Analysis\Python\Redbus\BA13.csv")
df14 = pd.read_csv(r"C:\Users\anees\Data Analysis\Python\Redbus\BA14.csv")
df15 = pd.read_csv(r"C:\Users\anees\Data Analysis\Python\Redbus\BA15.csv")
df16 = pd.read_csv(r"C:\Users\anees\Data Analysis\Python\Redbus\BA16.csv")
df17 = pd.read_csv(r"C:\Users\anees\Data Analysis\Python\Redbus\BA17.csv")
df18 =pd.read_csv(r"C:\Users\anees\Data Analysis\Python\Redbus\BA18.csv")
df19 = pd.read_csv(r"C:\Users\anees\Data Analysis\Python\Redbus\BA19.csv")
df20 = pd.read_csv(r"C:\Users\anees\Data Analysis\Python\Redbus\BA20.csv")
df21 =pd.read_csv(r"C:\Users\anees\Data Analysis\Python\Redbus\BA21.csv")
df22 = pd.read_csv(r"C:\Users\anees\Data Analysis\Python\Redbus\BA22.csv")

# %%
DFF1 = pd.concat([df1,df2,df3,df4,df5,df6,df7,df8,df9,df10,df11,df12,df13,df14,df15,df16,df17,df18,df19,df20,df21,df22],axis = 0)

# %%
DFF1
# Out:
#     Unnamed: 0                  PickUp             Drop  \
# 0            0             City Centre        Esplanade
# 1            1     GT Road Gandhi C...         Babughat
# 2            2    City Center Durgapur      Karunamoyee
# 3            3    City Center Durgapur      Karunamoyee
# 4            4    City Center Durgapur      Karunamoyee
# ..         ...                     ...              ...
# 9            9       Barasat bus Stand        Bus Stand
# 10          10       Barasat bus Stand            Digha
# 11          11  Barasat Chapadali More        Bus Stand
# 12          12       Barasat bus Stand            Digha
# 13          13       Barasat bus Stand  Digha Bus Stand
#
#                                     Bus_Type Total_Time   Bus_Name  \
# 0    Scania Multi-Axle AC Semi Sleeper (2+2)      04 00      Royal
# 1             Non A/C Seater / Sleeper (2+1)      04 00      Pammi
# 2                     Volvo A/C Seater (2+2)      03 10   SHYAMOLI
# ...

# %%
DFF1.drop("Unnamed: 0",axis = 1,inplace = True)

# %%
DFF1
# Out:
#                     PickUp             Drop  \
# 0              City Centre        Esplanade
# 1      GT Road Gandhi C...         Babughat
# 2     City Center Durgapur      Karunamoyee
# 3     City Center Durgapur      Karunamoyee
# 4     City Center Durgapur      Karunamoyee
# ..                     ...              ...
# 9        Barasat bus Stand        Bus Stand
# 10       Barasat bus Stand            Digha
# 11  Barasat Chapadali More        Bus Stand
# 12       Barasat bus Stand            Digha
# 13       Barasat bus Stand  Digha Bus Stand
#
#                                     Bus_Type Total_Time   Bus_Name  \
# 0    Scania Multi-Axle AC Semi Sleeper (2+2)      04 00      Royal
# 1             Non A/C Seater / Sleeper (2+1)      04 00      Pammi
# 2                     Volvo A/C Seater (2+2)      03 10   SHYAMOLI
# 3   Volvo 9600 Multi Axle Semi-Sleeper (2+2)      03 10    Express
# 4                     Volvo A/C Seater (2+2)      03 10   SHYAMOLI
# ...

# %%
df1 = pd.read_csv(r"C:\Users\anees\Data Analysis\Python\Redbus\HI1.csv")
df2 = pd.read_csv(r"C:\Users\anees\Data Analysis\Python\Redbus\HI2.csv")
df3 = pd.read_csv(r"C:\Users\anees\Data Analysis\Python\Redbus\HI3.csv")
df4 = pd.read_csv(r"C:\Users\anees\Data Analysis\Python\Redbus\HI4.csv")
df5 = pd.read_csv(r"C:\Users\anees\Data Analysis\Python\Redbus\HI5.csv")
df6 = pd.read_csv(r"C:\Users\anees\Data Analysis\Python\Redbus\HI6.csv")
df7 = pd.read_csv(r"C:\Users\anees\Data Analysis\Python\Redbus\HI7.csv")
df8 = pd.read_csv(r"C:\Users\anees\Data Analysis\Python\Redbus\HI8.csv")
df9 = pd.read_csv(r"C:\Users\anees\Data Analysis\Python\Redbus\HI9.csv")
df10 = pd.read_csv(r"C:\Users\anees\Data Analysis\Python\Redbus\HI10.csv")
df11 = pd.read_csv(r"C:\Users\anees\Data Analysis\Python\Redbus\HI11.csv")
df12 = pd.read_csv(r"C:\Users\anees\Data Analysis\Python\Redbus\HI12.csv")
df13 = pd.read_csv(r"C:\Users\anees\Data Analysis\Python\Redbus\HI13.csv")
df14 = pd.read_csv(r"C:\Users\anees\Data Analysis\Python\Redbus\HI14.csv")
df15 = pd.read_csv(r"C:\Users\anees\Data Analysis\Python\Redbus\HI15.csv")
df16 = pd.read_csv(r"C:\Users\anees\Data Analysis\Python\Redbus\HI16.csv")
df17 = pd.read_csv(r"C:\Users\anees\Data Analysis\Python\Redbus\HI17.csv")
df18 =pd.read_csv(r"C:\Users\anees\Data Analysis\Python\Redbus\HI18.csv")
df19 = pd.read_csv(r"C:\Users\anees\Data Analysis\Python\Redbus\HI19.csv")
df20 = pd.read_csv(r"C:\Users\anees\Data Analysis\Python\Redbus\HI20.csv")
df21 =pd.read_csv(r"C:\Users\anees\Data Analysis\Python\Redbus\HI21.csv")
df22 = pd.read_csv(r"C:\Users\anees\Data Analysis\Python\Redbus\HI22.csv")
df23 = pd.read_csv(r"C:\Users\anees\Data Analysis\Python\Redbus\HI23.csv")
df24 = pd.read_csv(r"C:\Users\anees\Data Analysis\Python\Redbus\HI24.csv")
df25 = pd.read_csv(r"C:\Users\anees\Data Analysis\Python\Redbus\HI25.csv")
df26= pd.read_csv(r"C:\Users\anees\Data Analysis\Python\Redbus\HI26.csv")
df27 = pd.read_csv(r"C:\Users\anees\Data Analysis\Python\Redbus\HI27.csv")

# %%
DFF2 = pd.concat([df1,df2,df3,df4,df5,df6,df7,df8,df9,df10,df11,df12,df13,df14,df15,df16,df17,df18,df19,df20,df21,df22,df23,df24,df25,df26,df27],axis = 0)

# %%
DFF2
# Out:
#     Unnamed: 0               PickUp                           Drop  \
# 0            0                DELHI                         SHIMLA
# 1            1   ISBT Kashmiri Gate                  Pass Crossing
# 2            2       Majnu Ka Tilla                         Shimla
# 3            3   ISBT Kashmiri Gate          bypass MC car parking
# 4            4   ISBT Kashmiri Gate  Shimla By pass Mc Car Parking
# ..         ...                  ...                            ...
# 46          46               Manali                 Majnu Ka Tilla
# 47          47               Manali                 Majnu Ka Tilla
# 48          48               Manali                 Majnu Ka Tilla
# 49          49               Manali                 Majnu Ka Tilla
# 50          50  Private Bus Parking  Kashmere Gate Metro Station G
#
#                                         Bus_Type Total_Time        Bus_Name  \
# 0      Super Luxury Volvo AC Seater Pushback 2+2      11 00           RSRTC
# ...

# %%
DFF2.drop("Unnamed: 0",axis = 1,inplace = True)

# %%
DFF2
# Out:
#                  PickUp                           Drop  \
# 0                 DELHI                         SHIMLA
# 1    ISBT Kashmiri Gate                  Pass Crossing
# 2        Majnu Ka Tilla                         Shimla
# 3    ISBT Kashmiri Gate          bypass MC car parking
# 4    ISBT Kashmiri Gate  Shimla By pass Mc Car Parking
# ..                  ...                            ...
# 46               Manali                 Majnu Ka Tilla
# 47               Manali                 Majnu Ka Tilla
# 48               Manali                 Majnu Ka Tilla
# 49               Manali                 Majnu Ka Tilla
# 50  Private Bus Parking  Kashmere Gate Metro Station G
#
#                                         Bus_Type Total_Time        Bus_Name  \
# 0      Super Luxury Volvo AC Seater Pushback 2+2      11 00           RSRTC
# 1                   Volvo A/C Semi Sleeper (2+2)      09 00            Bedi
# ...

# %%
df1 = pd.read_csv(r"C:\Users\anees\Data Analysis\Python\Redbus\UT1.csv")
df2 = pd.read_csv(r"C:\Users\anees\Data Analysis\Python\Redbus\UT2.csv")
df3 = pd.read_csv(r"C:\Users\anees\Data Analysis\Python\Redbus\UT3.csv")
df4 = pd.read_csv(r"C:\Users\anees\Data Analysis\Python\Redbus\UT4.csv")
df5 = pd.read_csv(r"C:\Users\anees\Data Analysis\Python\Redbus\UT5.csv")
df6 = pd.read_csv(r"C:\Users\anees\Data Analysis\Python\Redbus\UT6.csv")
df7 = pd.read_csv(r"C:\Users\anees\Data Analysis\Python\Redbus\UT7.csv")
df8 = pd.read_csv(r"C:\Users\anees\Data Analysis\Python\Redbus\UT8.csv")
df9 = pd.read_csv(r"C:\Users\anees\Data Analysis\Python\Redbus\UT9.csv")
df10 = pd.read_csv(r"C:\Users\anees\Data Analysis\Python\Redbus\UT10.csv")
df11 = pd.read_csv(r"C:\Users\anees\Data Analysis\Python\Redbus\UT11.csv")
df12 = pd.read_csv(r"C:\Users\anees\Data Analysis\Python\Redbus\UT12.csv")
df13 = pd.read_csv(r"C:\Users\anees\Data Analysis\Python\Redbus\UT13.csv")
df14 = pd.read_csv(r"C:\Users\anees\Data Analysis\Python\Redbus\UT14.csv")
df15 = pd.read_csv(r"C:\Users\anees\Data Analysis\Python\Redbus\UT15.csv")
df16 = pd.read_csv(r"C:\Users\anees\Data Analysis\Python\Redbus\UT16.csv")
df17 = pd.read_csv(r"C:\Users\anees\Data Analysis\Python\Redbus\UT17.csv")
df18 =pd.read_csv(r"C:\Users\anees\Data Analysis\Python\Redbus\UT18.csv")
df19 = pd.read_csv(r"C:\Users\anees\Data Analysis\Python\Redbus\UT19.csv")
df20 = pd.read_csv(r"C:\Users\anees\Data Analysis\Python\Redbus\UT20.csv")
df21 =pd.read_csv(r"C:\Users\anees\Data Analysis\Python\Redbus\UT21.csv")
df22 = pd.read_csv(r"C:\Users\anees\Data Analysis\Python\Redbus\UT22.csv")
df23 = pd.read_csv(r"C:\Users\anees\Data Analysis\Python\Redbus\UT23.csv")
df24 = pd.read_csv(r"C:\Users\anees\Data Analysis\Python\Redbus\UT24.csv")
df25 = pd.read_csv(r"C:\Users\anees\Data Analysis\Python\Redbus\UT25.csv")
df26= pd.read_csv(r"C:\Users\anees\Data Analysis\Python\Redbus\UT26.csv")
df27 = pd.read_csv(r"C:\Users\anees\Data Analysis\Python\Redbus\UT27.csv")
df28 = pd.read_csv(r"C:\Users\anees\Data Analysis\Python\Redbus\UT28.csv")
df29 = pd.read_csv(r"C:\Users\anees\Data Analysis\Python\Redbus\UT29.csv")
df30 = pd.read_csv(r"C:\Users\anees\Data Analysis\Python\Redbus\UT30.csv")
df31 = pd.read_csv(r"C:\Users\anees\Data Analysis\Python\Redbus\UT31.csv")
df32 = pd.read_csv(r"C:\Users\anees\Data Analysis\Python\Redbus\UT32.csv")
df33 = pd.read_csv(r"C:\Users\anees\Data Analysis\Python\Redbus\UT33.csv")
df34 = pd.read_csv(r"C:\Users\anees\Data Analysis\Python\Redbus\UT34.csv")
df35 = pd.read_csv(r"C:\Users\anees\Data Analysis\Python\Redbus\UT35.csv")
df36 = pd.read_csv(r"C:\Users\anees\Data Analysis\Python\Redbus\UT36.csv")
df37 = pd.read_csv(r"C:\Users\anees\Data Analysis\Python\Redbus\UT37.csv")
df38 = pd.read_csv(r"C:\Users\anees\Data Analysis\Python\Redbus\UT38.csv")
df39 = pd.read_csv(r"C:\Users\anees\Data Analysis\Python\Redbus\UT39.csv")
df40 = pd.read_csv(r"C:\Users\anees\Data Analysis\Python\Redbus\UT40.csv")
df41 =pd.read_csv(r"C:\Users\anees\Data Analysis\Python\Redbus\UT41.csv")

# %%
DFF3 = pd.concat([df1,df2,df3,df4,df5,df6,df7,df8,df9,df10,df11,df12,df13,df14,df15,df16,df17,df18,df19,df20,df21,df22,df23,df24,df25,df26,df27,df28,df29,df30,df31,df32,df33,df34,df35,df36,df37,df38,df39,df40,df41],axis = 0)

# %%
DFF3
# Out:
#     Unnamed: 0                      PickUp                         Drop  \
# 0            0  Kaushambi Bus Stand(Delhi)  BAREILLY SATELITE BUS STAND
# 1            1  Kaushambi Bus Stand(Delhi)  BAREILLY SATELITE BUS STAND
# 2            2                 Anand Vihar  BAREILLY SATELITE BUS STAND
# 3            3  Kaushambi Bus Stand(Delhi)  BAREILLY SATELITE BUS STAND
# 4            4           NOIDA BUS STATION            BAREILLY SATELITE
# ..         ...                         ...                          ...
# 6            6  ETAH BUS STATION BUS STAND                        Delhi
# 7            7      chaturvedi bus service                   Pickup Van
# 8            8      chaturvedi bus service                          NaN
# 9            9      chaturvedi bus service                 Sangam Vihar
# 10          10      chaturvedi bus service      Loni Kacha Balram Nagar
#
#                          Bus_Type Total_Time    Bus_Name            From_To  \
# ...

# %%
DFF3.drop("Unnamed: 0",axis = 1,inplace = True)

# %%
DFF3
# Out:
#                         PickUp                         Drop  \
# 0   Kaushambi Bus Stand(Delhi)  BAREILLY SATELITE BUS STAND
# 1   Kaushambi Bus Stand(Delhi)  BAREILLY SATELITE BUS STAND
# 2                  Anand Vihar  BAREILLY SATELITE BUS STAND
# 3   Kaushambi Bus Stand(Delhi)  BAREILLY SATELITE BUS STAND
# 4            NOIDA BUS STATION            BAREILLY SATELITE
# ..                         ...                          ...
# 6   ETAH BUS STATION BUS STAND                        Delhi
# 7       chaturvedi bus service                   Pickup Van
# 8       chaturvedi bus service                          NaN
# 9       chaturvedi bus service                 Sangam Vihar
# 10      chaturvedi bus service      Loni Kacha Balram Nagar
#
#                          Bus_Type Total_Time    Bus_Name            From_To  \
# 0           Janrath AC Seater 2+3      05 00      UPSRTC  delhi-to-bareilly
# 1           Janrath AC Seater 2+2      04 44      UPSRTC  delhi-to-bareilly
# ...

# %%
dfff = pd.concat([DFF1,DFF2,DFF3],axis = 0)

# %%
dfff
# Out:
#                         PickUp                     Drop  \
# 0                  City Centre                Esplanade
# 1          GT Road Gandhi C...                 Babughat
# 2         City Center Durgapur              Karunamoyee
# 3         City Center Durgapur              Karunamoyee
# 4         City Center Durgapur              Karunamoyee
# ..                         ...                      ...
# 6   ETAH BUS STATION BUS STAND                    Delhi
# 7       chaturvedi bus service               Pickup Van
# 8       chaturvedi bus service                      NaN
# 9       chaturvedi bus service             Sangam Vihar
# 10      chaturvedi bus service  Loni Kacha Balram Nagar
#
#                                     Bus_Type Total_Time    Bus_Name  \
# 0    Scania Multi-Axle AC Semi Sleeper (2+2)      04 00       Royal
# 1             Non A/C Seater / Sleeper (2+1)      04 00       Pammi
# 2                     Volvo A/C Seater (2+2)      03 10    SHYAMOLI
# ...

# %%
anee = pd.concat([df,dfff],axis = 0)

# %%
anee
# Out:
#                         PickUp                     Drop  \
# 0                   Bala Nagar            Bommalasatram
# 1                 Chanda Nagar            RTC Bus Stand
# 2                 Chanda Nagar                 Nandyala
# 3                     Malakpet       noonepalli flyover
# 4                     LB Nagar       noonepalli flyover
# ..                         ...                      ...
# 6   ETAH BUS STATION BUS STAND                    Delhi
# 7       chaturvedi bus service               Pickup Van
# 8       chaturvedi bus service                      NaN
# 9       chaturvedi bus service             Sangam Vihar
# 10      chaturvedi bus service  Loni Kacha Balram Nagar
#
#                           Bus_Type Total_Time    Bus_Name  \
# 0   Non A/C Seater / Sleeper (2+1)      06 30        Indu
# 1      NON AC Seater / Sleeper 2+1      06 50         BRS
# 2                A/C Sleeper (2+1)      07 15         BRS
# ...

# %%
#anee.to_csv("table2.csv")

# %%
df = pd.read_csv(r"C:\Users\anees\Data Analysis\Python\Redbus\table2.csv")

# %%
df
# Out:
#       Unnamed: 0                      PickUp                     Drop  \
# 0              0                  Bala Nagar            Bommalasatram
# 1              1                Chanda Nagar            RTC Bus Stand
# 2              2                Chanda Nagar                 Nandyala
# 3              3                    Malakpet       noonepalli flyover
# 4              4                    LB Nagar       noonepalli flyover
# ...          ...                         ...                      ...
# 9538           6  ETAH BUS STATION BUS STAND                    Delhi
# 9539           7      chaturvedi bus service               Pickup Van
# 9540           8      chaturvedi bus service                      NaN
# 9541           9      chaturvedi bus service             Sangam Vihar
# 9542          10      chaturvedi bus service  Loni Kacha Balram Nagar
#
#                             Bus_Type Total_Time    Bus_Name  \
# 0     Non A/C Seater / Sleeper (2+1)      06 30        Indu
# ...

# %%
df1 = pd.read_csv(r"C:\Users\anees\Data Analysis\Python\Redbus\WB1.csv")
df2 = pd.read_csv(r"C:\Users\anees\Data Analysis\Python\Redbus\WB2.csv")
df3 = pd.read_csv(r"C:\Users\anees\Data Analysis\Python\Redbus\WB3.csv")
df4 = pd.read_csv(r"C:\Users\anees\Data Analysis\Python\Redbus\WB4.csv")
df5 = pd.read_csv(r"C:\Users\anees\Data Analysis\Python\Redbus\WB5.csv")
df6 = pd.read_csv(r"C:\Users\anees\Data Analysis\Python\Redbus\WB6.csv")
df7 = pd.read_csv(r"C:\Users\anees\Data Analysis\Python\Redbus\WB7.csv")
df8 = pd.read_csv(r"C:\Users\anees\Data Analysis\Python\Redbus\WB8.csv")
df9 = pd.read_csv(r"C:\Users\anees\Data Analysis\Python\Redbus\WB9.csv")
df10 = pd.read_csv(r"C:\Users\anees\Data Analysis\Python\Redbus\WB10.csv")
df11 = pd.read_csv(r"C:\Users\anees\Data Analysis\Python\Redbus\WB11.csv")
df12 = pd.read_csv(r"C:\Users\anees\Data Analysis\Python\Redbus\WB12.csv")
df13 = pd.read_csv(r"C:\Users\anees\Data Analysis\Python\Redbus\WB13.csv")
df14 = pd.read_csv(r"C:\Users\anees\Data Analysis\Python\Redbus\WB14.csv")
df15 = pd.read_csv(r"C:\Users\anees\Data Analysis\Python\Redbus\WB15.csv")
df16 = pd.read_csv(r"C:\Users\anees\Data Analysis\Python\Redbus\WB16.csv")
df17 = pd.read_csv(r"C:\Users\anees\Data Analysis\Python\Redbus\WB17.csv")
df18 =pd.read_csv(r"C:\Users\anees\Data Analysis\Python\Redbus\WB18.csv")
df19 = pd.read_csv(r"C:\Users\anees\Data Analysis\Python\Redbus\WB19.csv")
df20 = pd.read_csv(r"C:\Users\anees\Data Analysis\Python\Redbus\WB20.csv")

# %%
DFF1 = pd.concat([df1,df2,df3,df4,df5,df6,df7,df8,df9,df10,df11,df12,df13,df14,df15,df16,df17,df18,df19,df20],axis = 0)

# %%
DFF1
# Out:
#     Unnamed: 0           PickUp                  Drop  \
# 0            0  Digha Bus Stand     Barasat bus Stand
# 1            1        Bus Stand     Barasat bus Stand
# 2            2            Digha     Barasat bus Stand
# 3            3            Digha     Barasat bus Stand
# 4            4        Bus Stand     Barasat bus Stand
# ..         ...              ...                   ...
# 0            0        Esplanade               Mayapur
# 1            1        Esplanade               Mayapur
# 0            0        Esplanade                HALDIA
# 1            1           Dunlop    Durgachak Bus stop
# 0            0            Habra  Durgapur City Center
#
#                       Bus_Type Total_Time       Bus_Name             From_To  \
# 0   A/C Seater / Sleeper (2+2)      06 20            The    digha-to-barasat
# 1             A/C Seater (2+3)      05 25        Arunita    digha-to-barasat
# 2   A/C Seater / Sleeper (2+2)      05 20       Aradhana    digha-to-barasat
# ...

# %%
df1 = pd.read_csv(r"C:\Users\anees\Data Analysis\Python\Redbus\CG1.csv")
df2 = pd.read_csv(r"C:\Users\anees\Data Analysis\Python\Redbus\CG2.csv")
df3 = pd.read_csv(r"C:\Users\anees\Data Analysis\Python\Redbus\CG3.csv")
df4 = pd.read_csv(r"C:\Users\anees\Data Analysis\Python\Redbus\CG4.csv")
df5 = pd.read_csv(r"C:\Users\anees\Data Analysis\Python\Redbus\CG5.csv")
df6 = pd.read_csv(r"C:\Users\anees\Data Analysis\Python\Redbus\CG6.csv")
df7 = pd.read_csv(r"C:\Users\anees\Data Analysis\Python\Redbus\CG7.csv")
df8 = pd.read_csv(r"C:\Users\anees\Data Analysis\Python\Redbus\CG8.csv")
df9 = pd.read_csv(r"C:\Users\anees\Data Analysis\Python\Redbus\CG9.csv")
df10 = pd.read_csv(r"C:\Users\anees\Data Analysis\Python\Redbus\CG10.csv")
df11 = pd.read_csv(r"C:\Users\anees\Data Analysis\Python\Redbus\CG11.csv")
df12 = pd.read_csv(r"C:\Users\anees\Data Analysis\Python\Redbus\CG12.csv")
df13 = pd.read_csv(r"C:\Users\anees\Data Analysis\Python\Redbus\CG13.csv")
df14 = pd.read_csv(r"C:\Users\anees\Data Analysis\Python\Redbus\CG14.csv")
df15 = pd.read_csv(r"C:\Users\anees\Data Analysis\Python\Redbus\CG15.csv")
df16 = pd.read_csv(r"C:\Users\anees\Data Analysis\Python\Redbus\CG16.csv")
df17 = pd.read_csv(r"C:\Users\anees\Data Analysis\Python\Redbus\CG17.csv")
df18 =pd.read_csv(r"C:\Users\anees\Data Analysis\Python\Redbus\CG18.csv")
df19 = pd.read_csv(r"C:\Users\anees\Data Analysis\Python\Redbus\CG19.csv")
df20 = pd.read_csv(r"C:\Users\anees\Data Analysis\Python\Redbus\CG20.csv")
df21 =pd.read_csv(r"C:\Users\anees\Data Analysis\Python\Redbus\CG21.csv")
df22 = pd.read_csv(r"C:\Users\anees\Data Analysis\Python\Redbus\CG22.csv")
df23 = pd.read_csv(r"C:\Users\anees\Data Analysis\Python\Redbus\CG23.csv")
df24 = pd.read_csv(r"C:\Users\anees\Data Analysis\Python\Redbus\CG24.csv")
df25 = pd.read_csv(r"C:\Users\anees\Data Analysis\Python\Redbus\CG25.csv")
df26= pd.read_csv(r"C:\Users\anees\Data Analysis\Python\Redbus\CG26.csv")
df27 = pd.read_csv(r"C:\Users\anees\Data Analysis\Python\Redbus\CG27.csv")

# %%
DFF2 = pd.concat([df1,df2,df3,df4,df5,df6,df7,df8,df9,df10,df11,df12,df13,df14,df15,df16,df17,df18,df19,df20,df21,df22,df23,df24,df25,df26,df27],axis = 0)

# %%
DFF2
# Out:
#     Unnamed: 0                            PickUp                    Drop  \
# 0            0                    Yamuna by pass   karan filling station
# 1            1                      Yamuna Nagar     HP Petrol Pump Oppo
# 2            2  Near hp petrol pump sarsawa b...                    Sec
# 0            0                           Airport      ISBT Kashmiri Gate
# 1            1                                 B      ISBT Kashmiri Gate
# ..         ...                               ...                     ...
# 5            5                         Bus Stand                Firozpur
# 6            6                         Bus Stand                Firozpur
# 7            7                         Bus Stand                Firozpur
# 8            8                            mohali         Cantt bus stand
# 9            9                            mohali         Cantt bus stand
#
#                                  Bus_Type Total_Time   Bus_Name  \
# ...

# %%
df1 = pd.read_csv(r"C:\Users\anees\Data Analysis\Python\Redbus\JK1.csv")
df2 = pd.read_csv(r"C:\Users\anees\Data Analysis\Python\Redbus\JK2.csv")
df3 = pd.read_csv(r"C:\Users\anees\Data Analysis\Python\Redbus\JK3.csv")
df4 = pd.read_csv(r"C:\Users\anees\Data Analysis\Python\Redbus\JK4.csv")
df5 = pd.read_csv(r"C:\Users\anees\Data Analysis\Python\Redbus\JK5.csv")
df6 = pd.read_csv(r"C:\Users\anees\Data Analysis\Python\Redbus\JK6.csv")

# %%
DFF3 = pd.concat([df1,df2,df3,df4,df5,df6],axis = 0)

# %%
DFF3
# Out:
#     Unnamed: 0                            PickUp  \
# 0            0  Mitha Couh Office Batmallu Bu...
# 1            1            Pantha Chowk Bus Stand
# 0            0          Trikuta Shopping Complex
# 1            1          Trikuta Shopping Complex
# 2            2          Trikuta Shopping Complex
# 3            3  Trikuta Complex KC Chowk Shop...
# 4            4                     BC Road Jammu
# 5            5          Trikuta Shopping Complex
# 6            6                   Trikuta Complex
# 7            7          Trikuta Shopping Complex
# 8            8          Trikuta Shopping Complex
# 9            9                           I S B T
# 10          10               BC Road (Bus Stand)
# 11          11                   Trikuta Complex
# 12          12          Trikuta Shopping Complex
# 13          13                             jammu
# 14          14                           I S B T
# 15          15          Trikuta Shopping Complex
# ...

# %%
df1 = pd.read_csv(r"C:\Users\anees\Data Analysis\Python\Redbus\AS1.csv")
df2 = pd.read_csv(r"C:\Users\anees\Data Analysis\Python\Redbus\AS2.csv")
df3 = pd.read_csv(r"C:\Users\anees\Data Analysis\Python\Redbus\AS3.csv")
df4 = pd.read_csv(r"C:\Users\anees\Data Analysis\Python\Redbus\AS4.csv")
df5 = pd.read_csv(r"C:\Users\anees\Data Analysis\Python\Redbus\AS5.csv")
df6 = pd.read_csv(r"C:\Users\anees\Data Analysis\Python\Redbus\AS6.csv")

# %%
DFF4 = pd.concat([df1,df2,df3,df4,df5,df6],axis = 0)

# %%
DFF4
# Out:
#    Unnamed: 0             PickUp                Drop  \
# 0           0    Diphu Bus Stand       ISBT Guwahati
# 1           1    Diphu Bus Stand           Khanapara
# 2           2    Diphu Bus Stand           Khanapara
# 3           3    Diphu Bus Stand           Khanapara
# 0           0  Dokmoka Bus Stand       ISBT Guwahati
# 1           1  Dokmoka Bus Stand           Khanapara
# 2           2  Dokmoka Bus Stand           Khanapara
# 3           3  Dokmoka Bus Stand           Khanapara
# 0           0  Bokolia Bus Stand       ISBT Guwahati
# 1           1  Bokolia Bus Stand           Khanapara
# 2           2  Bokolia Bus Stand           Khanapara
# 3           3  Bokolia Bus Stand           Khanapara
# 0           0  Langhin Bus Stand       ISBT Guwahati
# 1           1  Langhin Bus Stand           Khanapara
# 2           2  Langhin Bus Stand           Khanapara
# 3           3  Langhin Bus Stand           Khanapara
# 0           0     Bus Stop Manja       ISBT Guwahati
# ...

# %%
df1 = pd.read_csv(r"C:\Users\anees\Data Analysis\Python\Redbus\BH1.csv")
df2 = pd.read_csv(r"C:\Users\anees\Data Analysis\Python\Redbus\BH2.csv")
df3 = pd.read_csv(r"C:\Users\anees\Data Analysis\Python\Redbus\BH3.csv")
df4 = pd.read_csv(r"C:\Users\anees\Data Analysis\Python\Redbus\BH4.csv")
df5 = pd.read_csv(r"C:\Users\anees\Data Analysis\Python\Redbus\BH5.csv")
df6 = pd.read_csv(r"C:\Users\anees\Data Analysis\Python\Redbus\BH6.csv")
df7 = pd.read_csv(r"C:\Users\anees\Data Analysis\Python\Redbus\BH7.csv")
df8 = pd.read_csv(r"C:\Users\anees\Data Analysis\Python\Redbus\BH8.csv")
df9 = pd.read_csv(r"C:\Users\anees\Data Analysis\Python\Redbus\BH9.csv")
df10 = pd.read_csv(r"C:\Users\anees\Data Analysis\Python\Redbus\BH10.csv")
df11 = pd.read_csv(r"C:\Users\anees\Data Analysis\Python\Redbus\BH11.csv")
df12 = pd.read_csv(r"C:\Users\anees\Data Analysis\Python\Redbus\BH12.csv")
df13 = pd.read_csv(r"C:\Users\anees\Data Analysis\Python\Redbus\BH13.csv")
df14 = pd.read_csv(r"C:\Users\anees\Data Analysis\Python\Redbus\BH14.csv")
df15 = pd.read_csv(r"C:\Users\anees\Data Analysis\Python\Redbus\BH15.csv")
df16 = pd.read_csv(r"C:\Users\anees\Data Analysis\Python\Redbus\BH16.csv")
df17 = pd.read_csv(r"C:\Users\anees\Data Analysis\Python\Redbus\BH17.csv")
df18 =pd.read_csv(r"C:\Users\anees\Data Analysis\Python\Redbus\BH18.csv")
df19 = pd.read_csv(r"C:\Users\anees\Data Analysis\Python\Redbus\BH19.csv")

# %%
DFF5 = pd.concat([df1,df2,df3,df4,df5,df6,df7,df8,df9,df10,df11,df12,df13,df14,df15,df16,df17,df18,df19],axis = 0)

# %%
DFF5
# Out:
#     Unnamed: 0                            PickUp             Drop  \
# 0            0  Banjari mod by pass gopalganj...      Anand Vihar
# 1            1                      BANJARI MORE   Badarpur BODER
# 2            2                         Gopalganj      Anand Vihar
# 3            3                         Gopalganj      Anand Vihar
# 4            4            Banjari Mod, Gopalganj      Anand Vihar
# ..         ...                               ...              ...
# 8            8            Banjari Mod, Gopalganj         Alambagh
# 9            9  Banjari mod by pass gopalganj...         Charbagh
# 10          10                         Gopalganj         Charbagh
# 11          11                      BANJARI MORE  Transport Nagar
# 12          12                         Gopalganj         Charbagh
#
#                       Bus_Type Total_Time  Bus_Name               From_To  \
# 0   A/C Seater / Sleeper (2+2)      14 30    Travel    gopalganj-to-delhi
# ...

# %%
df1 = pd.read_csv(r"C:\Users\anees\Data Analysis\Python\Redbus\PJ1.csv")
df2 = pd.read_csv(r"C:\Users\anees\Data Analysis\Python\Redbus\PJ2.csv")
df3 = pd.read_csv(r"C:\Users\anees\Data Analysis\Python\Redbus\PJ3.csv")
df4 = pd.read_csv(r"C:\Users\anees\Data Analysis\Python\Redbus\PJ4.csv")
df5 = pd.read_csv(r"C:\Users\anees\Data Analysis\Python\Redbus\PJ5.csv")
df6 = pd.read_csv(r"C:\Users\anees\Data Analysis\Python\Redbus\PJ6.csv")
df7 = pd.read_csv(r"C:\Users\anees\Data Analysis\Python\Redbus\PJ7.csv")
df8 = pd.read_csv(r"C:\Users\anees\Data Analysis\Python\Redbus\PJ8.csv")
df9 = pd.read_csv(r"C:\Users\anees\Data Analysis\Python\Redbus\PJ9.csv")

# %%
DFF6 = pd.concat([df1,df2,df3,df4,df5,df6,df7,df8,df9],axis = 0)

# %%
DFF6
# Out:
#     Unnamed: 0                            PickUp                Drop  \
# 0            0                New Bus stand P...  ISBT Kashmiri Gate
# 1            1                New Bus stand P...  ISBT Kashmiri Gate
# 2            2                New Bus stand P...  ISBT Kashmiri Gate
# 3            3                New Bus stand P...  ISBT Kashmiri Gate
# 0            0                     Sherpur Chowk  ISBT Kashmiri Gate
# ..         ...                               ...                 ...
# 5            5  Pick by shared cab from amrit...        departure ga
# 0            0             Bus Stand , Jalandhar            Terminal
# 1            1                  Jalandhar Bypass            Terminal
# 2            2                  Jalandhar Bypass            Terminal
# 3            3                  Jalandhar Bypass            Terminal
#
#                          Bus_Type Total_Time Bus_Name  \
# 0              AC Seater Hvac 2+2      05 01    PEPSU
# ...

# %%
dff1 = pd.concat([DFF1,DFF2,DFF3,DFF4,DFF5,DFF6],axis =0)

# %%
dff1
# Out:
#     Unnamed: 0                            PickUp               Drop  \
# 0            0                   Digha Bus Stand  Barasat bus Stand
# 1            1                         Bus Stand  Barasat bus Stand
# 2            2                             Digha  Barasat bus Stand
# 3            3                             Digha  Barasat bus Stand
# 4            4                         Bus Stand  Barasat bus Stand
# ..         ...                               ...                ...
# 5            5  Pick by shared cab from amrit...       departure ga
# 0            0             Bus Stand , Jalandhar           Terminal
# 1            1                  Jalandhar Bypass           Terminal
# 2            2                  Jalandhar Bypass           Terminal
# 3            3                  Jalandhar Bypass           Terminal
#
#                       Bus_Type Total_Time  Bus_Name  \
# 0   A/C Seater / Sleeper (2+2)      06 20       The
# ...

# %%
ani = pd.concat([df,dff1],axis = 0)

# %%
ani
# Out:
#     Unnamed: 0.1  Unnamed: 0                            PickUp  \
# 0            0.0           0                        Bala Nagar
# 1            1.0           1                      Chanda Nagar
# 2            2.0           2                      Chanda Nagar
# 3            3.0           3                          Malakpet
# 4            4.0           4                          LB Nagar
# ..           ...         ...                               ...
# 5            NaN           5  Pick by shared cab from amrit...
# 0            NaN           0             Bus Stand , Jalandhar
# 1            NaN           1                  Jalandhar Bypass
# 2            NaN           2                  Jalandhar Bypass
# 3            NaN           3                  Jalandhar Bypass
#
#                   Drop                        Bus_Type Total_Time Bus_Name  \
# 0        Bommalasatram  Non A/C Seater / Sleeper (2+1)      06 30     Indu
# ...

# %%
ani.drop("Unnamed: 0",axis = 1,inplace = True)

# %%
ani
# Out:
#                               PickUp                Drop  \
# 0                         Bala Nagar       Bommalasatram
# 1                       Chanda Nagar       RTC Bus Stand
# 2                       Chanda Nagar            Nandyala
# 3                           Malakpet  noonepalli flyover
# 4                           LB Nagar  noonepalli flyover
# ..                               ...                 ...
# 5   Pick by shared cab from amrit...        departure ga
# 0              Bus Stand , Jalandhar            Terminal
# 1                   Jalandhar Bypass            Terminal
# 2                   Jalandhar Bypass            Terminal
# 3                   Jalandhar Bypass            Terminal
#
#                           Bus_Type Total_Time Bus_Name  \
# 0   Non A/C Seater / Sleeper (2+1)      06 30     Indu
# 1      NON AC Seater / Sleeper 2+1      06 50      BRS
# 2                A/C Sleeper (2+1)      07 15      BRS
# ...

# %%
ani.to_csv("final_bus.csv")

# %%
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\anees\Data Analysis\Python\Redbus\final_bus.csv")

# %%
df
# Out:
#        Unnamed: 0                            PickUp                Drop  \
# 0               0                        Bala Nagar       Bommalasatram
# 1               1                      Chanda Nagar       RTC Bus Stand
# 2               2                      Chanda Nagar            Nandyala
# 3               3                          Malakpet  noonepalli flyover
# 4               4                          LB Nagar  noonepalli flyover
# ...           ...                               ...                 ...
# 11882           5  Pick by shared cab from amrit...        departure ga
# 11883           0             Bus Stand , Jalandhar            Terminal
# 11884           1                  Jalandhar Bypass            Terminal
# 11885           2                  Jalandhar Bypass            Terminal
# 11886           3                  Jalandhar Bypass            Terminal
#
#                              Bus_Type Total_Time Bus_Name  \
# ...

# %%
df.drop("Unnamed: 0",axis = 1,inplace = True)

# %%
df
# Out:
#                                  PickUp                Drop  \
# 0                            Bala Nagar       Bommalasatram
# 1                          Chanda Nagar       RTC Bus Stand
# 2                          Chanda Nagar            Nandyala
# 3                              Malakpet  noonepalli flyover
# 4                              LB Nagar  noonepalli flyover
# ...                                 ...                 ...
# 11882  Pick by shared cab from amrit...        departure ga
# 11883             Bus Stand , Jalandhar            Terminal
# 11884                  Jalandhar Bypass            Terminal
# 11885                  Jalandhar Bypass            Terminal
# 11886                  Jalandhar Bypass            Terminal
#
#                              Bus_Type Total_Time Bus_Name  \
# 0      Non A/C Seater / Sleeper (2+1)      06 30     Indu
# 1         NON AC Seater / Sleeper 2+1      06 50      BRS
# 2                   A/C Sleeper (2+1)      07 15      BRS
# ...

# %%
df["From_To"].unique()
# Out:
# array(['hyderabad-to-nandyala', 'khammam-to-hyderabad',
#        'hyderabad-to-khammam', 'hyderabad-to-srisailam',
#        'karimnagar-to-hyderabad', 'hyderabad-to-mancherial',
#        'hyderabad-to-karimnagar', 'hyderabad-to-nirmal',
#        'hyderabad-to-adilabad', 'hyderabad-to-ongole',
#        'kothagudem-to-hyderabad', 'guntur-to-hyderabad',
#        'hyderabad-to-guntur', 'hyderabad-to-kothagudem',
#        'hyderabad-to-sathupalli', 'hyderabad-to-warangal',
#        'kodad-to-hyderabad', 'jagityal-to-hyderabad',
#        'hyderabad-to-bhadrachalam', 'hyderabad-to-tirupathi',
#        'hyderabad-to-godavarikhani', 'hyderabad-to-armoor',
#        'hyderabad-to-vijayawada', 'vijayawada-to-hyderabad',
#        'kakinada-to-visakhapatnam', 'bangalore-to-tirupathi',
#        'bangalore-to-kadapa', 'ongole-to-hyderabad',
#        'kadapa-to-bangalore', 'visakhapatnam-to-kakinada',
#        'chittoor-to-bangalore', 'bangalore-to-ananthapur',
# ...

# %%
df["State"].unique()
# Out:
# array(['TSRTC', 'APRTC', 'GOA', 'KERALA', 'RAJASTHAN', 'SOUTH BENGAL',
#        'HIMACHAL', 'UTTAR PRADESH', 'WEST BENGAL', 'CHANDIGARH',
#        'JUMMU KASHMIR', 'ASSAM', 'BIHAR', 'PUNJAB'], dtype=object)

# %%
df.rename(columns={"PickUp":"Departed","Drop":"Arrival"})
# Out:
#                                Departed             Arrival  \
# 0                            Bala Nagar       Bommalasatram
# 1                          Chanda Nagar       RTC Bus Stand
# 2                          Chanda Nagar            Nandyala
# 3                              Malakpet  noonepalli flyover
# 4                              LB Nagar  noonepalli flyover
# ...                                 ...                 ...
# 11882  Pick by shared cab from amrit...        departure ga
# 11883             Bus Stand , Jalandhar            Terminal
# 11884                  Jalandhar Bypass            Terminal
# 11885                  Jalandhar Bypass            Terminal
# 11886                  Jalandhar Bypass            Terminal
#
#                              Bus_Type Total_Time Bus_Name  \
# 0      Non A/C Seater / Sleeper (2+1)      06 30     Indu
# 1         NON AC Seater / Sleeper 2+1      06 50      BRS
# 2                   A/C Sleeper (2+1)      07 15      BRS
# ...

# %%
df.rename(columns={"Drop":"Arrival"})
# Out:
#                                  PickUp             Arrival  \
# 0                            Bala Nagar       Bommalasatram
# 1                          Chanda Nagar       RTC Bus Stand
# 2                          Chanda Nagar            Nandyala
# 3                              Malakpet  noonepalli flyover
# 4                              LB Nagar  noonepalli flyover
# ...                                 ...                 ...
# 11882  Pick by shared cab from amrit...        departure ga
# 11883             Bus Stand , Jalandhar            Terminal
# 11884                  Jalandhar Bypass            Terminal
# 11885                  Jalandhar Bypass            Terminal
# 11886                  Jalandhar Bypass            Terminal
#
#                              Bus_Type Total_Time Bus_Name  \
# 0      Non A/C Seater / Sleeper (2+1)      06 30     Indu
# 1         NON AC Seater / Sleeper 2+1      06 50      BRS
# 2                   A/C Sleeper (2+1)      07 15      BRS
# ...
